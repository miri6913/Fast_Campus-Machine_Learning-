# %%
# ▶ Warnings 제거
import warnings
warnings.filterwarnings('ignore')

# # ▶ Google drive mount or 폴더 클릭 후 구글드라이브 연결
# from google.colab import drive
# drive.mount('/content/drive')

# ▶ 경로 설정 
# import os
# os.chdir('/content/drive/MyDrive/Colab Notebooks/00.Fast_campus/04.ML_signature/PROC/data')
# # '과제 파일이 위치한 경로를 입력'
# os.getcwd()

# %% [markdown]
# # **01. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ 숫자형 & 문자형 변수 구분**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 데이터를 Read하고, 숫자형 변수와 문자형 변수의 COl으로 나누시오**
#
# > **출력형태**
#
# ```
# * 숫자형 변수 : ['col1', 'col2', ...]
# * 문자형 변수 : ['col3', 'col4', ...]
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('Data/exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
import numpy as np
import pandas as pd
# ▶ numeric, categorical value 나누기
numerical_list=[] # 숫자형 변수를 담아두기 위한 빈 List 생성
categorical_list=[] # 문자형 변수를 담다주기 위한 빈 List 생성

for i in df.columns : # for문을 활용하여 DataFrame에 있는 Col(컬럼) list들을 하나씩 루프(loop)를 수행함 
  if df[i].dtypes == 'O' : # dtypes == 'O'라는 말은 'Object'의 줄임말로서 자료형 형태(문자형)를 나타냄
    categorical_list.append(i) # 상위 if문 조건에서 Col의 타입이 자료형인 경우에는 문자형 변수 List에 해당 내용을 추가함
  else :
    numerical_list.append(i) # 그렇지 않은 경우 숫자형 변수 List에 루프(loop)를 돌고있는 col 명을 추가함


print("숫자형 변수:", numerical_list) # 최종적으로 숫자형 변수 List를 출력
print("문자형 변수:", categorical_list) # 최종적으로 문자형 변수 List를 출력
# Out:
# 숫자형 변수: ['Quantity', 'UnitPrice', 'CustomerID']
# 문자형 변수: ['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country']

# %% [markdown]
# # **02. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ Pivot_table 활용**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 데이터를 Read하고, pd.pivot_table기능을 활용하여 년월 기준으로 거래건수를 카운트 하시오**
#
# > **출력형태**
#
# ```
# * index : 'InvoiceDate' Column을 활용하여 년도와 월을 추출
# * 추출한 index를 활용하여 InvoiceNo Col(열)에 대해 Count 수행
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 새로 추출한 InvoiceDate를 index에 넣고, InvoiceNo를 Count함 
df.pivot_table(index=['InvoiceDate'], values=['InvoiceNo'], aggfunc= 'count')
# Out:
#              InvoiceNo
# InvoiceDate
# 2010-12          42481
# 2011-01          35147
# 2011-02          27707
# 2011-03          36748
# 2011-04          29916
# 2011-05          37030
# 2011-06          36874
# 2011-07          39518
# 2011-08          35284
# 2011-09          50226
# 2011-10          60742
# 2011-11          84711
# 2011-12          25525

# %% [markdown]
# # **03. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ Encoding 변환**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, label-encoding을 활용하여 문자형 변수를 Encoding하시오**
#
# > **출력형태**
#
# ```
# * from sklearn.preprocessing import LabelEncoder 활용
# * 문자형 변수 모두 변환
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
import numpy as np
import pandas as pd
# ▶ numeric, categorical value 나누기
numerical_list=[] # 숫자형 변수를 담아두기 위한 빈 List 생성
categorical_list=[] # 문자형 변수를 담다주기 위한 빈 List 생성

for i in df.columns : # for문을 활용하여 DataFrame에 있는 Col(컬럼) list들을 하나씩 루프(loop)를 수행함 
  if df[i].dtypes == 'O' : # dtypes == 'O'라는 말은 'Object'의 줄임말로서 자료형 형태(문자형)를 나타냄
    categorical_list.append(i) # 상위 if문 조건에서 Col의 타입이 자료형인 경우에는 문자형 변수 List에 해당 내용을 추가함
  else :
    numerical_list.append(i) # 그렇지 않은 경우 숫자형 변수 List에 루프(loop)를 돌고있는 col 명을 추가함


print("숫자형 변수:", numerical_list) # 최종적으로 숫자형 변수 List를 출력
print("문자형 변수:", categorical_list) # 최종적으로 문자형 변수 List를 출력
# Out:
# 숫자형 변수: ['Quantity', 'UnitPrice', 'CustomerID']
# 문자형 변수: ['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country']

# %%
from sklearn.preprocessing import LabelEncoder # LabelEncoder load

for col in categorical_list: # 이전 단계에서 구분한 Categorical_list를 활용하여 LabelEncoder에 문자형 변수를 각각 할당함
    print(col)
    le = LabelEncoder() # LabelEncoder 모델을 생성 (※ 학습전)
    le.fit(df[col]) # for문을 통해 전달받은 문자형 변수 List들에 대해서 학습(Fitting)
    df[col] = le.transform(df[col]) # transform 명령어를 통해, 기존 문자형 데이터를 수치형 데이터로 변환

df[categorical_list] # 최종적으로 변환한 categorical_list를 출력하고, 변환 결과를 확인
# Out:
# InvoiceNo
# StockCode
# Description
# InvoiceDate
# Country
#         InvoiceNo  StockCode  Description  InvoiceDate  Country
# 0               0       3536         3918         6838       36
# 1               0       2794         3926         6838       36
# 2               0       3044          913         6838       36
# 3               0       2985         1910         6838       36
# 4               0       2984         2911         6838       36
# ...           ...        ...          ...          ...      ...
# 541904      22060       1527         2379         9391       13
# 541905      22060       1803          743         9391       13
# 541906      22060       2145          749         9391       13
# 541907      22060       2146          748         9391       13
# 541908      22060       1093          304         9391       13
#
# [541909 rows x 5 columns]

# %% [markdown]
# # **04. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ NaN Value 처리**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, NaN Value를 처리하시오**
#
# > **출력형태**
#
# ```
# * 'CustomerID'기준으로 NaN일시 모두 Drop
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ isnull() 명령어를 통해서 col별 Null 값을 True/False로 출력
df.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# 0            False    False
# 1            False    False
# 2            False    False
# 3            False    False
# 4            False    False
# ...            ...      ...
# 541904       False    False
# 541905       False    False
# 541906       False    False
# 541907       False    False
# 541908       False    False
#
# [541909 rows x 8 columns]

# %%
# ▶ sum() 명령어를 추가로 실행하여, Col별 NaN 개수 출력 
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# ▶ dropna 명령어를 통해서 'CustomerID' NaN 값이 들어있는 행기준(axis=0)으로 Drop
df = df.dropna(subset=['CustomerID'], axis=0)

# %%
# ▶ 최종 NaN value 확인 이상 무
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# # **05. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ Zero Ratio 출력**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 숫자형 변수 col 대상으로 0에 비율을 확인하시오**
#
# > **출력형태**
#
# ```
# * 주어진 데이터에서 숫자형 변수 대상으로만 zero(0)에 비율을 계산하시오
# * 숫자형 변수 Col별로 %로 표현되어야함
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
import numpy as np
import pandas as pd
# ▶ numeric, categorical value 나누기
numerical_list=[] # 숫자형 변수를 담아두기 위한 빈 List 생성
categorical_list=[] # 문자형 변수를 담다주기 위한 빈 List 생성

for i in df.columns : # for문을 활용하여 DataFrame에 있는 Col(컬럼) list들을 하나씩 루프(loop)를 수행함 
  if df[i].dtypes == 'O' : # dtypes == 'O'라는 말은 'Object'의 줄임말로서 자료형 형태(문자형)를 나타냄
    categorical_list.append(i) # 상위 if문 조건에서 Col의 타입이 자료형인 경우에는 문자형 변수 List에 해당 내용을 추가함
  else :
    numerical_list.append(i) # 그렇지 않은 경우 숫자형 변수 List에 루프(loop)를 돌고있는 col 명을 추가함


print("숫자형 변수:", numerical_list) # 최종적으로 숫자형 변수 List를 출력
print("문자형 변수:", categorical_list) # 최종적으로 문자형 변수 List를 출력
# Out:
# 숫자형 변수: ['Quantity', 'UnitPrice', 'CustomerID']
# 문자형 변수: ['InvoiceNo', 'StockCode', 'Description', 'InvoiceDate', 'Country']

# %%
# ▶ numerical list 확인
df[numerical_list]
# Out:
#         Quantity  UnitPrice  CustomerID
# 0              6       2.55     17850.0
# 1              6       3.39     17850.0
# 2              8       2.75     17850.0
# 3              6       3.39     17850.0
# 4              6       3.39     17850.0
# ...          ...        ...         ...
# 541904        12       0.85     12680.0
# 541905         6       2.10     12680.0
# 541906         4       4.15     12680.0
# 541907         4       4.15     12680.0
# 541908         3       4.95     12680.0
#
# [541909 rows x 3 columns]

# %%
len(df[df['UnitPrice'] == 0])
# Out:
# 2515

# %%
# ▶ Zero 비율 확인
list_of_df = [] # Zero 비율을 작성할 빈 List 생성

for i in numerical_list : # 상위 단계에서 구한 numerical_list를 하나씩 For문을 통과시킴
 loof_df = pd.DataFrame({'val' : [i],
                         'zero_cnt': len(df[df[i] == 0])}) # 각 val별 0인 값을 카운트하고, 변수명과 카운트수를 가지고 있는 DatFrame을 생성함
 list_of_df.append(loof_df) # 생성한 DataFrame을 처음 단계에서 생성한 빈 List에 append 시키면서 모든 Val에 대해서 실행
 
df_merge  = pd.concat(list_of_df).reset_index(drop=True) # 최종적으로 concat명령어를 사용하면 list들을 병합하여 하나의 DataFrame을 생성할 수 있음
df_merge['zero_ratio'] = df_merge['zero_cnt'] / len(df) # zero_cnt를 전체 데이터 개수로 나눠주게 되면 zero_ratio를 구할 수 있음
df_merge.sort_values(by=['zero_ratio'], ascending = False) # zero_ratio 기준으로 내림차순 정렬 후 코드 종료
# Out:
#           val  zero_cnt  zero_ratio
# 1   UnitPrice      2515    0.004641
# 0    Quantity         0    0.000000
# 2  CustomerID         0    0.000000

# %% [markdown]
# # **06. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ Data Type 재정의**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 잘 못 정의되어 있는 Col을 올바른 Type으로 재정의 하시오**
#
# > **출력형태**
#
# ```
# * CustomerID의 현재 Data type을 확인하고, 문자형(str, object) type으로 변경
# * CustomerID를 소수점 아래에 단위는 버리고 숫자만 표현 ex) 17850.0 → 17850
# * 변환 이전에 NA Value 00000으로 변경 후 진행
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ dtype 명령어를 활용하여 CustomerID col의 현재 데이터 타입 확인
df['CustomerID'].dtype # float 타입으로 선언되어 있음
# Out:
# dtype('O')

# %%
# ▶ CustomerID 
df['CustomerID'].head() # 문자로 변환하기 전에 소수점으로 표현된 내용 삭제 필요
# Out:
# 0    17850
# 1    17850
# 2    17850
# 3    17850
# 4    17850
# Name: CustomerID, dtype: object

# %%
# ▶ NaN Value가 존재하면 astype 명령어 실행 시 error가 발생하기 때문에, 사전에 NaN value처리가 필요함
df['CustomerID'] = df['CustomerID'].fillna(00000)

# %%
# ▶ float type을 int형태로 변환하여 소수점 자리를 삭제하고, 다시 astype(str) 명령어를 통해 문자열 형태로 변환
df['CustomerID'] = df['CustomerID'].astype(int).astype(str)
df['CustomerID'].head()
# Out:
# 0    17850
# 1    17850
# 2    17850
# 3    17850
# 4    17850
# Name: CustomerID, dtype: object

# %% [markdown]
# # **07. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ 중복 데이터 처리**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 중복데이터를 처리하시오**
#
# > **출력형태**
#
# ```
# * 모든 Col을 기준으로 중복인 데이터를 삭제하고, 변경된 데이터 개수를 기존과 비교하여 출력하시오
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 중복된 데이터 개수 확인
df.duplicated().value_counts()
# Out:
# False    536641
# True       5268
# dtype: int64

# %%
# ▶ duplicated(keep=False) 명령어를 활용하면, 모든 중복된 row에 대해서 True를 부여하므로 중복된 데이터를 직접 확인할 수 있음
df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head()
# Out:
#     InvoiceNo StockCode                    Description  Quantity  \
# 494    536409     21866    UNION JACK FLAG LUGGAGE TAG         1
# 517    536409     21866    UNION JACK FLAG LUGGAGE TAG         1
# 485    536409     22111   SCOTTIE DOG HOT WATER BOTTLE         1
# 539    536409     22111   SCOTTIE DOG HOT WATER BOTTLE         1
# 489    536409     22866  HAND WARMER SCOTTY DOG DESIGN         1
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# 494  12/1/2010 11:45       1.25     17908.0  United Kingdom
# 517  12/1/2010 11:45       1.25     17908.0  United Kingdom
# 485  12/1/2010 11:45       4.95     17908.0  United Kingdom
# 539  12/1/2010 11:45       4.95     17908.0  United Kingdom
# 489  12/1/2010 11:45       2.10     17908.0  United Kingdom

# %%
# ▶ drop_duplicates 명령어를 통해 모든 col이 중복되는 row를 삭제한다. 
df_unique = df.drop_duplicates()

# %%
# ▶ 중복 제거 전/후 개수 비교
len(df), len(df_unique)
# Out:
# (541909, 536641)

# %% [markdown]
# # **08. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ Outlier 처리**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 요청한 기준에 맞게 Outlier를 처리하시오**
#
# > **출력형태**
#
# ```
# * Quantity 및 UnitPrice는 음수값이 존재할 수 없음
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 문제가 되고 있는 Col에 분포를 파악하기 위해 describe() 명령어를 통해 확인
df['Quantity'].describe()
# Out:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
# ▶ 문제가 되고 있는 Col에 분포를 파악하기 위해 describe() 명령어를 통해 확인
df['UnitPrice'].describe()
# Out:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
# ▶ 문제의 조건에 맞게 음수값을 제거하고 df를 다시 구성
df = df[df['Quantity']>0]
df = df[df['UnitPrice']>0]

# %%
# ▶ 정상 변환 확인
df['Quantity'].describe()
# Out:
# count    530104.000000
# mean         10.542037
# std         155.524124
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
# ▶ 정상 변환 확인
df['UnitPrice'].describe()
# Out:
# count    530104.000000
# mean          3.907625
# std          35.915681
# min           0.001000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       13541.330000
# Name: UnitPrice, dtype: float64

# %% [markdown]
# # **09. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅ 시간 데이터 활용 변수생성**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 시간 Type의 변수를 선언하고, 이를 활용하여 다양한 변수를 추출하시오**
#
# > **출력형태**
#
# ```
# * 대상 Col : InvoiceDate
# * 추출 변수 : Month, Day, Hour
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ InvoiceDate를 시간 Type으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# ▶ dt.month/day/hour 명령어를 통해 문제에서 요구한 추가 변수 추출
df['Month'] = df['InvoiceDate'].dt.month
df['Day'] = df['InvoiceDate'].dt.day
df['Hour'] = df['InvoiceDate'].dt.hour

# %%
df['InvoiceDate', 'Month', 'Day', 'Hour']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
# ▶ 최종 추출된 변수 확인
df[['InvoiceDate', 'Month', 'Day', 'Hour']]
# Out:
#                InvoiceDate  Month  Day  Hour
# 0      2010-12-01 08:26:00     12    1     8
# 1      2010-12-01 08:26:00     12    1     8
# 2      2010-12-01 08:26:00     12    1     8
# 3      2010-12-01 08:26:00     12    1     8
# 4      2010-12-01 08:26:00     12    1     8
# ...                    ...    ...  ...   ...
# 541904 2011-12-09 12:50:00     12    9    12
# 541905 2011-12-09 12:50:00     12    9    12
# 541906 2011-12-09 12:50:00     12    9    12
# 541907 2011-12-09 12:50:00     12    9    12
# 541908 2011-12-09 12:50:00     12    9    12
#
# [541909 rows x 4 columns]

# %% [markdown]
# # **10. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅Unique Value 출력**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, Col별 Unique한 Value를 추출하는 반복문을 만드시오**
#
# > **출력형태**
#
# ```
# * for문 활용 모든 Col의 Unique한 Value를 print
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ for문 활용 df.columns list를 인자로 전달받아서, nunique() 명령어를 통해 Col별 Unique한 val를 출력
for i in df.columns :
  print(f'{i} / Unique val : {df[i].nunique()}')
# Out:
# InvoiceNo / Unique val : 25900
# StockCode / Unique val : 4070
# Description / Unique val : 4223
# Quantity / Unique val : 722
# InvoiceDate / Unique val : 23260
# UnitPrice / Unique val : 1630
# CustomerID / Unique val : 4372
# Country / Unique val : 38

# %%
df.nunique()
# Out:
# InvoiceNo      25900
# StockCode       4070
# Description     4223
# Quantity         722
# InvoiceDate    23260
# UnitPrice       1630
# CustomerID      4372
# Country           38
# dtype: int64

# %% [markdown]
# # **11. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅연속형 변수 구간화(Binning)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, UnitPrice를 주어진 조건으로 가공 후, 구간화(binning) 하시오**
#
# > **출력형태**
#
# ```
# * UnitPrice > 0 조건 적용
# * pd.cut 명령어를 활용하여 구간화 진행
# * 구간화 : [0, 25%, 50%, 75%, max]
# * 25% / 50% / 75% 구간은 describe() 명령어를 통해 계산
# * 최종적으로 구간화한 내용을 기준으로 데이터를 카운트 수행
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ UnitPrice 조건 적용 
df = df[df['UnitPrice']>0]
df['UnitPrice'].describe()
# Out:
# count    539392.000000
# mean          4.673648
# std          94.614722
# min           0.001000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
df['UnitPrice_gp'] = pd.cut(df['UnitPrice'], [0, 1.25, 2.08, 4.13, 38970], labels= ['gp1', 'gp2', 'gp3', 'gp4'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country UnitPrice_gp
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom          gp3
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom          gp3
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom          gp3
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom          gp3
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom          gp3
# ...                 ...        ...         ...             ...          ...
# 541904  12/9/2011 12:50       0.85     12680.0          France          gp1
# 541905  12/9/2011 12:50       2.10     12680.0          France          gp3
# 541906  12/9/2011 12:50       4.15     12680.0          France          gp4
# 541907  12/9/2011 12:50       4.15     12680.0          France          gp4
# 541908  12/9/2011 12:50       4.95     12680.0          France          gp4
#
# [539392 rows x 9 columns]

# %%
df.groupby('UnitPrice_gp')['InvoiceNo']

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country UnitPrice_gp
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom          gp3
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom          gp3
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom          gp3
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom          gp3
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom          gp3
# ...                 ...        ...         ...             ...          ...
# 541904  12/9/2011 12:50       0.85     12680.0          France          gp1
# 541905  12/9/2011 12:50       2.10     12680.0          France          gp3
# 541906  12/9/2011 12:50       4.15     12680.0          France          gp4
# 541907  12/9/2011 12:50       4.15     12680.0          France          gp4
# 541908  12/9/2011 12:50       4.95     12680.0          France          gp4
#
# [539392 rows x 9 columns]

# %%
# ▶ 상위 결과에서 [0, 25%, 50%, 75%, max] 값들을 활용하여, pd.cut 수행 
df['UnitPrice_gp'] = pd.cut(df['UnitPrice'], [0, 1.25, 2.08, 4.13, 38970], labels= ['gp1', 'gp2', 'gp3', 'gp4'])
df.groupby('UnitPrice_gp')['InvoiceNo'].count()
# Out:
# UnitPrice_gp
# gp1    164868
# gp2    105106
# gp3    140503
# gp4    128915
# Name: InvoiceNo, dtype: int64

# %% [markdown]
# # **12. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정 조건 만족 데이터 추출(1)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 아래 조건을 만족하는 데이터를 추출하시오**
#
# > **출력형태**
#
# ```
# * Quantity가 10이상이면서, 2010년 12월 1일에 결제한 모든 거래 데이터 추출
# * 최종 추출된 데이터의 개수 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ InvoiceDate 시간 Type으로 변환 및 df.strftime 명령어를 통해 년월일 형식으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['ymd'] = df['InvoiceDate'].dt.strftime("%Y%m%d")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country       ymd
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom  20101201
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20101201
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom  20101201
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20101201
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20101201

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
#  8   ymd          541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 37.2+ MB

# %%
# ▶ '20101201' & Quantity > 10 조건에 맞는 데이터만을 추출
df[(df['Quantity'] > 10) & (df['ymd'] =='20101201')]
# Out:
#      InvoiceNo StockCode                       Description  Quantity  \
# 9       536367     84879     ASSORTED COLOUR BIRD ORNAMENT        32
# 26      536370     22728         ALARM CLOCK BAKELIKE PINK        24
# 27      536370     22727         ALARM CLOCK BAKELIKE RED         24
# 28      536370     22726        ALARM CLOCK BAKELIKE GREEN        12
# 29      536370     21724   PANDA AND BUNNIES STICKER SHEET        12
# ...        ...       ...                               ...       ...
# 2972    536592     84950    ASSORTED COLOUR T-LIGHT HOLDER        18
# 3061    536594    84970L  SINGLE HEART ZINC T-LIGHT HOLDER        12
# 3064    536595     21137          BLACK RECORD COVER FRAME        60
# 3065    536595     22041      RECORD FRAME 7" SINGLE SIZE         24
# 3103    536597    35271S              GOLD PRINT PAPER BAG        14
#
#              InvoiceDate  UnitPrice  CustomerID         Country       ymd
# 9    2010-12-01 08:34:00       1.69     13047.0  United Kingdom  20101201
# 26   2010-12-01 08:45:00       3.75     12583.0          France  20101201
# 27   2010-12-01 08:45:00       3.75     12583.0          France  20101201
# 28   2010-12-01 08:45:00       3.75     12583.0          France  20101201
# 29   2010-12-01 08:45:00       0.85     12583.0          France  20101201
# ...                  ...        ...         ...             ...       ...
# 2972 2010-12-01 17:06:00       0.99         NaN  United Kingdom  20101201
# 3061 2010-12-01 17:22:00       0.95     15235.0  United Kingdom  20101201
# 3064 2010-12-01 17:24:00       3.39     13576.0  United Kingdom  20101201
# 3065 2010-12-01 17:24:00       2.55     13576.0  United Kingdom  20101201
# 3103 2010-12-01 17:35:00       0.19     18011.0  United Kingdom  20101201
#
# [607 rows x 9 columns]

# %%
# ▶ 최종 데이터 개수 확인
len(df[(df['Quantity'] > 10) & (df['ymd'] =='20101201')])
# Out:
# 607

# %% [markdown]
# # **13. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정 조건 만족 데이터 추출(2)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,다음 명령어를 사용하여 특정 조건에 맞는 데이터를 추출하시오**
#
# > **출력형태**
#
# ```
# * isin()과 notnull() 명령어를 사용할 것
# * StockCode가 (84029E, 84406B, 85123A)를 포함하는 데이터
# * CustomerID가 Null 값이 아닌 데이터
# * 상위 2조건을 동시에 만족하는 데이터 추출
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
len(df[df['CustomerID'].notnull()])
# Out:
# 406829

# %%
# ▶ 문제에서 요구한 Stockcode가 포함되어 있는 데이터 추출
df[df['StockCode'].isin(['84029E', '84406B', '85123A']) & df['CustomerID'].notnull()]
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 0         536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 2         536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
# 4         536365    84029E      RED WOOLLY HOTTIE WHITE HEART.         6
# 49        536373    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 51        536373    84406B      CREAM CUPID HEARTS COAT HANGER         8
# ...          ...       ...                                 ...       ...
# 539979    581452    85123A  WHITE HANGING HEART T-LIGHT HOLDER        32
# 540170    581469    84029E      RED WOOLLY HOTTIE WHITE HEART.         1
# 540217    581472    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 540393    581480    84029E      RED WOOLLY HOTTIE WHITE HEART.         8
# 541639    581538    85123A  CREAM HANGING HEART T-LIGHT HOLDER         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 49       12/1/2010 9:02       2.55     17850.0  United Kingdom
# 51       12/1/2010 9:02       2.75     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 539979  12/8/2011 18:03       2.55     17675.0  United Kingdom
# 540170  12/8/2011 19:28       4.25     14606.0  United Kingdom
# 540217  12/8/2011 19:55       2.95     15796.0  United Kingdom
# 540393   12/9/2011 9:07       4.25     14441.0  United Kingdom
# 541639  12/9/2011 11:34       2.95     14446.0  United Kingdom
#
# [2660 rows x 8 columns]

# %% [markdown]
# # **14. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅apply-lambda 구문활용 데이터 처리**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, apply-lambda 구문을 활용하여 데이터를 처리하시오**
#
# > **출력형태**
#
# ```
# * InvocieDate를 '/' 구분자 기준으로 Split하고, 년, 월, 일을 추출
# * 추출한 년, 월, 일을 기존 데이터 프레임에 추가
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ apply(lambda x:)명령어는 목표가 되는 타겟 X에 대해서 사용자 정의함수를 모두 실행함
# '/'구분자 기준으로 날짜를 분할하여 원하는 값들을 [n] 인자를 통해서 추출하고, str.slice를 통해 원하는 부분만 추가 추출 진행
df['month'] = df['InvoiceDate'].apply(lambda x: x.split('/')[0])
df['day'] = df['InvoiceDate'].apply(lambda x: x.split('/')[1])
df['year'] = df['InvoiceDate'].apply(lambda x: x.split('/')[2]).str.slice(0,4)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country month day  year
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom    12   1  2010
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom    12   1  2010
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom    12   1  2010
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom    12   1  2010
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom    12   1  2010

# %% [markdown]
# # **15. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정값 원하는 값으로 변환**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 특정값을 원하는 값으료 변환하시오**
#
# > **출력형태**
#
# ```
# * replace 명령어를 활용하여 데이터를 변환하시오
# * Country Col의 'United Kingdom'을 'UK'로 치환하시오.
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
df.groupby('Country')['InvoiceNo'].count()
# Out:
# Country
# Australia                 1259
# Austria                    401
# Bahrain                     19
# Belgium                   2069
# Brazil                      32
# Canada                     151
# Channel Islands            758
# Cyprus                     622
# Czech Republic              30
# Denmark                    389
# EIRE                      8196
# European Community          61
# Finland                    695
# France                    8557
# Germany                   9495
# Greece                     146
# Hong Kong                  288
# Iceland                    182
# Israel                     297
# Italy                      803
# Japan                      358
# Lebanon                     45
# Lithuania                   35
# Malta                      127
# Netherlands               2371
# Norway                    1086
# Poland                     341
# Portugal                  1519
# RSA                         58
# Saudi Arabia                10
# Singapore                  229
# Spain                     2533
# Sweden                     462
# Switzerland               2002
# USA                        291
# United Arab Emirates        68
# United Kingdom          495478
# Unspecified                446
# Name: InvoiceNo, dtype: int64

# %%
# ▶ value_counts() 명령어를 통해 국가별 count 정보를 확인
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
# ▶ replace 명령어를 통해 기존 Data를 원하는 형태로 변경 진행
df['Country'] = df['Country'].replace('United Kingdom','UK')
df['Country'].value_counts()
# Out:
# UK                      495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# # **16. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅집계(Groupby) 활용 데이터 처리**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,집계(Groupby)명령어를 활용하여 조건에 만족하는 데이터를 추출하시오**
#
# > **출력형태**
#
# ```
# * Groupby 명령어를 활용할 것
# * CustomerID 기준으로 모든 상품의 구매한 수량(Quantity)과 평균 수량(Quatity) 추출
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
df.groupby('CustomerID')['Quantity']
# Out:
# CustomerID
# 12346.0      2
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
#           ...
# 18280.0     10
# 18281.0      7
# 18282.0     13
# 18283.0    756
# 18287.0     70
# Name: Quantity, Length: 4372, dtype: int64

# %%
# ▶ .agg([])명령어를 사용하면 groupby 기준으로 여러가지 산술계산을 동시에 진행할 수 있음
df.groupby('CustomerID')['Quantity'].agg(['sum', 'mean'])
# Out:
#              sum       mean
# CustomerID
# 12346.0        0   0.000000
# 12347.0     2458  13.505495
# 12348.0     2341  75.516129
# 12349.0      631   8.643836
# 12350.0      197  11.588235
# ...          ...        ...
# 18280.0       45   4.500000
# 18281.0       54   7.714286
# 18282.0       98   7.538462
# 18283.0     1397   1.847884
# 18287.0     1586  22.657143
#
# [4372 rows x 2 columns]

# %%
df.groupby('CustomerID')['Quantity'].agg(['sum', 'mean']).sort_values('sum', ascending=False)
# Out:
#                sum        mean
# CustomerID
# 14646.0     196719   94.349640
# 12415.0      77242   99.282776
# 14911.0      77180   13.074708
# 17450.0      69029  196.663818
# 18102.0      64122  148.087760
# ...            ...         ...
# 16252.0       -158   -7.523810
# 16742.0       -189  -47.250000
# 14213.0       -244  -48.800000
# 15823.0       -283  -16.647059
# 16546.0       -303   -9.774194
#
# [4372 rows x 2 columns]

# %% [markdown]
# # **17. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅Min-Max 정규화**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,Min-Max 정규화를 진행하시오.**
#
# > **출력형태**
#
# ```
# * from sklearn.preprocessing import minmax_scale 사용하여 정규화 진행
# * Quantity Col에 대한 Min-Max 정규화 진행하고, describe()명령어 수행 및 확인
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ minmax_scale 명령어를 통해 Quantity를 정규화함, axis=0으로 설정해줘야 row기준으로 표준화를 진행
from sklearn.preprocessing import minmax_scale
df['Quantity'] = minmax_scale(df['Quantity'], axis=0, copy=True)

# %%
df['Quantity'].describe()
# Out:
# count    541909.000000
# mean          0.500059
# std           0.001346
# min           0.000000
# 25%           0.500006
# 50%           0.500019
# 75%           0.500062
# max           1.000000
# Name: Quantity, dtype: float64

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        0.500059       4.611114   15287.690570
# std         0.001346      96.759853    1713.600303
# min         0.000000  -11062.060000   12346.000000
# 25%         0.500006       1.250000   13953.000000
# 50%         0.500019       2.080000   15152.000000
# 75%         0.500062       4.130000   16791.000000
# max         1.000000   38970.000000   18287.000000

# %% [markdown]
# # **18. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅지연(lag) 데이터 생성**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,shift명령어를 활용하여 지연(lag)데이터를 생성하시오**
#
# > **출력형태**
#
# ```
# * CustomerID 17850.0에 데이터만 가져와 새로운 DF 생성
# * DF에서 CustomerID, InvoiceDate Col만 남김
# * 중복 제거
# * 데이터를 구매시간 순으로 정렬
# * Shift명령어를 통해 이전 거래 일자를 의미하는 새로운 Col을 생성
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 문제에서 요구한 CustomerID만 가져와서 데이터를 구성
DF = df[df['CustomerID'] == 17850.0]
DF = DF[['CustomerID','InvoiceDate']]
DF.head()
# Out:
#    CustomerID     InvoiceDate
# 0     17850.0  12/1/2010 8:26
# 1     17850.0  12/1/2010 8:26
# 2     17850.0  12/1/2010 8:26
# 3     17850.0  12/1/2010 8:26
# 4     17850.0  12/1/2010 8:26

# %%
# ▶ drop_duplicates 명령어를 통해 중복 데이터 제거
DF = DF.drop_duplicates()
DF.head()
# Out:
#     CustomerID     InvoiceDate
# 0      17850.0  12/1/2010 8:26
# 7      17850.0  12/1/2010 8:28
# 47     17850.0  12/1/2010 9:01
# 49     17850.0  12/1/2010 9:02
# 66     17850.0  12/1/2010 9:32

# %%
# ▶ 날짜 기준으로 정렬 
DF = DF.sort_values(by=['InvoiceDate'])
DF.head()
# Out:
#      CustomerID      InvoiceDate
# 278     17850.0  12/1/2010 10:51
# 315     17850.0  12/1/2010 10:52
# 416     17850.0  12/1/2010 11:33
# 433     17850.0  12/1/2010 11:34
# 0       17850.0   12/1/2010 8:26

# %%
# ▶ shift 명렬어를 통해 1개씩 데이터를 지연 시킴 
DF['lag'] = DF['InvoiceDate'].shift(1)
DF.head()
# Out:
#      CustomerID      InvoiceDate              lag
# 278     17850.0  12/1/2010 10:51              NaN
# 315     17850.0  12/1/2010 10:52  12/1/2010 10:51
# 416     17850.0  12/1/2010 11:33  12/1/2010 10:52
# 433     17850.0  12/1/2010 11:34  12/1/2010 11:33
# 0       17850.0   12/1/2010 8:26  12/1/2010 11:34

# %% [markdown]
# # **19. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정 데이터 유형의 칼럼을 선택**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 숫자형 데이터만 출력하시오**
#
# > **출력형태**
#
# ```
# * pd.DataFrame.select_dtypes(include=None) 명령어를 사용하여 숫자형 데이터만을 출력하시오
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ select_dtypes(include='number')를 사용하면 숫자로 정의된 모든 COl을 식별할 수 있음
df.select_dtypes(include='number')
# Out:
#         Quantity  UnitPrice  CustomerID
# 0              6       2.55     17850.0
# 1              6       3.39     17850.0
# 2              8       2.75     17850.0
# 3              6       3.39     17850.0
# 4              6       3.39     17850.0
# ...          ...        ...         ...
# 541904        12       0.85     12680.0
# 541905         6       2.10     12680.0
# 541906         4       4.15     12680.0
# 541907         4       4.15     12680.0
# 541908         3       4.95     12680.0
#
# [541909 rows x 3 columns]

# %%
# ▶ select_dtypes(exclude='object')를 사용하여 objcet 타입을 제외하고 모든 col을 식별
df.select_dtypes(exclude='object')
# Out:
#         Quantity  UnitPrice  CustomerID
# 0              6       2.55     17850.0
# 1              6       3.39     17850.0
# 2              8       2.75     17850.0
# 3              6       3.39     17850.0
# 4              6       3.39     17850.0
# ...          ...        ...         ...
# 541904        12       0.85     12680.0
# 541905         6       2.10     12680.0
# 541906         4       4.15     12680.0
# 541907         4       4.15     12680.0
# 541908         3       4.95     12680.0
#
# [541909 rows x 3 columns]

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# # **20. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정 문자를 포함하는 행 가져오기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, str.contains 명령어를 활용하여 특정 문자를 포함하는 행을 출력하시오**
#
# > **출력형태**
#
# ```
# * .str.contains('', na=False)를 활용
# * Description에 'BOTTLE'이 포함된 행을 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ .str.contains(na=False) 명령어를 사용해 원하는 조건에 해당하는 데이터 추출
# na=False는 na 데이터가 존재할 시 필수적으로 설정해야함 
df[df['Description'].str.contains('BOTTLE', na=False)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 61        536373    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 78        536375    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 82        536376     22114    HOT WATER BOTTLE TEA AND SYMPATHY        48
# 190       536388     22915        ASSORTED BOTTLE TOP  MAGNETS         12
# ...          ...       ...                                  ...       ...
# 541751    581572     23328   SET 6 SCHOOL MILK BOTTLES IN CRATE        48
# 541870    581585     22915        ASSORTED BOTTLE TOP  MAGNETS         24
# 541877    581585     22113          GREY HEART HOT WATER BOTTLE         4
# 541878    581585     23356                LOVE HOT WATER BOTTLE         3
# 541887    581585     23328   SET 6 SCHOOL MILK BOTTLES IN CRATE         4
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 61       12/1/2010 9:02       3.39     17850.0  United Kingdom
# 78       12/1/2010 9:32       3.39     17850.0  United Kingdom
# 82       12/1/2010 9:32       3.45     15291.0  United Kingdom
# 190      12/1/2010 9:59       0.42     16250.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541751  12/9/2011 12:08       3.39     16705.0  United Kingdom
# 541870  12/9/2011 12:31       0.19     15804.0  United Kingdom
# 541877  12/9/2011 12:31       4.25     15804.0  United Kingdom
# 541878  12/9/2011 12:31       5.95     15804.0  United Kingdom
# 541887  12/9/2011 12:31       3.75     15804.0  United Kingdom
#
# [12242 rows x 8 columns]

# %% [markdown]
# # **21. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅%timeit 로 실행 시간 측정**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,%timeit 로 실행 시간 측정하시오**
#
# > **출력형태**
#
# ```
# * 코드를 자유롭게 입력하고, %timeit 매직 명령어를 통해 수행시간을 측정
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 실행명령어 앞에 %timeit를 입력하면 수행된 시간을 확인할 수 있음
import timeit
# %timeit df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
# %timeit df.head()
# Out:
# 711 ms ± 113 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 25.3 µs ± 1.27 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# # **22. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅Col 순서 변경하기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,주어진 조건에 맞게 Col 위치를 변경하시오**
#
# > **출력형태**
#
# ```
# * CustomerID를 맨 앞으로 배치할 것
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.shape
# Out:
# (541909, 8)

# %%
# ▶ [[]] 대괄호 2번을 사용하고 col순서를 재정의하면 원하는 컬럼의 순서로 변경할 수 있음
df = df[['CustomerID', 'InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice','Country']]
df.head()
# Out:
#    CustomerID InvoiceNo StockCode                          Description  \
# 0     17850.0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1     17850.0    536365     71053                  WHITE METAL LANTERN
# 2     17850.0    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3     17850.0    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4     17850.0    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity     InvoiceDate  UnitPrice         Country
# 0         6  12/1/2010 8:26       2.55  United Kingdom
# 1         6  12/1/2010 8:26       3.39  United Kingdom
# 2         8  12/1/2010 8:26       2.75  United Kingdom
# 3         6  12/1/2010 8:26       3.39  United Kingdom
# 4         6  12/1/2010 8:26       3.39  United Kingdom

# %% [markdown]
# # **23. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정 Col 이름 변경하기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,아래 조건에 맞게 Col명을 변경하시오**
#
# > **출력형태**
#
# ```
# * rename 명령어를 사용하여 CustomerID를 CID로 변경할 것
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ rename 명령어를 사용하면 특정 컬럼의 name을 원하는 값으로 변견할 수 있음
df = df.rename(columns = {'CustomerID': 'CID'})
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice      CID         Country
# 0  12/1/2010 8:26       2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39  17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75  17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39  17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39  17850.0  United Kingdom

# %% [markdown]
# # **24. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅Random Sampling**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 아래 조건에 맞게 임의추출을 진행하시오**
#
# > **출력형태**
#
# ```
# * 복원 추출
# * 비율 30%
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ sample을 통해 샘플링을 수행할 수 있고, frac은 추출 비율, replace 옵션을 통해 복원 추출 가능
df_s = df.sample(frac=0.3, replace = True, # fraction of axis items to return.
                random_state=1004)
df_s
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 240139    558087     21884          CAKES AND BOWS GIFT  TAPE         3
# 217119    555896    85099B            JUMBO BAG RED RETROSPOT        10
# 537925    581376     22867            HAND WARMER BIRD DESIGN         6
# 417806    572672     23201                 JUMBO BAG ALPHABET        20
# 117428    546387     22978                 PANTRY ROLLING PIN        12
# ...          ...       ...                                ...       ...
# 423182    573137     22595           GINGHAM HEART DECORATION         1
# 303333    563538     22465         HANGING METAL STAR LANTERN         1
# 414180    572353     21915             RED  HARMONICA IN BOX         12
# 414602    572472     22537       MAGIC DRAWING SLATE DINOSAUR        24
# 3937      536739     21527  RED RETROSPOT TRADITIONAL TEAPOT          2
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 240139   6/26/2011 12:04       0.65     17323.0  United Kingdom
# 217119    6/7/2011 16:04       2.08     15640.0  United Kingdom
# 537925   12/8/2011 12:43       2.10     14719.0  United Kingdom
# 417806  10/25/2011 13:15       2.08     13340.0  United Kingdom
# 117428   3/11/2011 13:34       3.75     16766.0  United Kingdom
# ...                  ...        ...         ...             ...
# 423182  10/27/2011 17:15       1.63         NaN  United Kingdom
# 303333   8/17/2011 11:48       1.65     17841.0  United Kingdom
# 414180  10/24/2011 11:40       1.25     15215.0  United Kingdom
# 414602  10/24/2011 13:34       0.42     14139.0  United Kingdom
# 3937     12/2/2010 13:08       7.95     14180.0  United Kingdom
#
# [162573 rows x 8 columns]

# %% [markdown]
# # **25. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅결측값 동시에 처리하기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,아래 조건에 맞게 결측값을 동시에 처리하시오**
#
# > **출력형태**
#
# ```
# * Description은 'Unknown' 문자열로 처리
# * CustomerID는 mean(평균)으로 처리
# * Dictionary를 사용하여 동시에 처리할 것
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
df.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# 0            False    False
# 1            False    False
# 2            False    False
# 3            False    False
# 4            False    False
# ...            ...      ...
# 541904       False    False
# 541905       False    False
# 541906       False    False
# 541907       False    False
# 541908       False    False
#
# [541909 rows x 8 columns]

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# ▶ null 값 확인
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df['CustomerID'].mean()
# Out:
# 15287.690570239585

# %%
df['CustomerID'].describe()
# Out:
# count    406829.000000
# mean      15287.690570
# std        1713.600303
# min       12346.000000
# 25%       13953.000000
# 50%       15152.000000
# 75%       16791.000000
# max       18287.000000
# Name: CustomerID, dtype: float64

# %%
# ▶ 문제에 조건에 맞는 컬럼별 처리 방법을 Dictionary화함
missing_fill_val = {'Description': 'Unknown', 
                    'CustomerID': df['CustomerID'].mean()}
print(missing_fill_val)
# Out:
# {'Description': 'Unknown', 'CustomerID': 15287.690570239585}

# %%
# ▶ fillna() 인자에 상위에서 정의한 Dictionary를 입력하면 기 정의된 방식으로 NA처리가 가능
df = df.fillna(missing_fill_val)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# # **26. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅rank활용 순위 생성**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,rank명령어를 사용하여 순위를 생성하시오**
#
# > **출력형태**
#
# ```
# * Quantity와 UnitPrice를 곱하여 Amt를 계산함
# * CustoemrID별로 총 구매금액을 계산함
# * Amt를 기준으로 rank(ascending=False), 순위 생성
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
df.groupby('CustomerID')['Amt'].sum()
# Out:
# CustomerID
# 12346.0       0.00
# 12347.0    4310.00
# 12348.0    1797.24
# 12349.0    1757.55
# 12350.0     334.40
#             ...
# 18280.0     180.60
# 18281.0      80.82
# 18282.0     176.60
# 18283.0    2094.88
# 18287.0    1837.28
# Name: Amt, Length: 4372, dtype: float64

# %%
# ▶ Amt 생성
df['Amt'] = df['UnitPrice'] * df['Quantity']
df = pd.DataFrame(df.groupby('CustomerID')['Amt'].sum()).reset_index()
df.head()
# Out:
#    CustomerID      Amt
# 0     12346.0     0.00
# 1     12347.0  4310.00
# 2     12348.0  1797.24
# 3     12349.0  1757.55
# 4     12350.0   334.40

# %%
df.sort_values(by='Amt', ascending=False)
# Out:
#       CustomerID        Amt
# 1703     14646.0  279489.02
# 4233     18102.0  256438.49
# 3758     17450.0  187482.17
# 1895     14911.0  132572.62
# 55       12415.0  123725.45
# ...          ...        ...
# 125      12503.0   -1126.00
# 3870     17603.0   -1165.30
# 1384     14213.0   -1192.20
# 2236     15369.0   -1592.49
# 3756     17448.0   -4287.63
#
# [4372 rows x 2 columns]

# %%
# ▶ .rank(ascending=False) 옵션을 통해 새로운 순위 컬럼 생성
df['Rank'] = df['Amt'].rank(ascending=False)
df.sort_values(by='Rank')
# Out:
#       CustomerID        Amt    Rank
# 1703     14646.0  279489.02     1.0
# 4233     18102.0  256438.49     2.0
# 3758     17450.0  187482.17     3.0
# 1895     14911.0  132572.62     4.0
# 55       12415.0  123725.45     5.0
# ...          ...        ...     ...
# 125      12503.0   -1126.00  4368.0
# 3870     17603.0   -1165.30  4369.0
# 1384     14213.0   -1192.20  4370.0
# 2236     15369.0   -1592.49  4371.0
# 3756     17448.0   -4287.63  4372.0
#
# [4372 rows x 3 columns]

# %% [markdown]
# # **27. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅그룹단위 통계량 추가하기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,CustomerID기준으로 통계량 값을 추가하시오**
#
# > **출력형태**
#
# ```
# * Quantity와 UnitPrice를 곱하여 Amt를 계산함
# * CustoemrID별로 평균 구매금액을 계산하여 새로운 Col으로 표현
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ Amt 생성 
df['Amt'] = df['UnitPrice'] * df['Quantity']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    Amt
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
# ▶ CustomerID기준으로 평균값을 구하기 위해서는 transform을 사용해야함 
df['Amt_mean_by_CID'] = df.groupby('CustomerID')['Amt'].transform('mean')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country    Amt  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
#
#    Amt_mean_by_CID
# 0        16.950737
# 1        16.950737
# 2        16.950737
# 3        16.950737
# 4        16.950737

# %% [markdown]
# # **28. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅두 개의 변수활용 새로운 변수 만들기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,두 개의 변수를 활용하여 새로운 변수를 만드시오**
#
# > **출력형태**
#
# ```
# * InvoiceNo와 StockCode를 결합하고 UID라는 col을 만드시오
# * 두 개의 Column을 합칠 때 '_'를 기준으로 합치시오
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
df[['InvoiceNo', 'StockCode']].apply(lambda x: '_'.join(x), axis=1)
# Out:
# 0         536365_85123A
# 1          536365_71053
# 2         536365_84406B
# 3         536365_84029G
# 4         536365_84029E
#               ...
# 541904     581587_22613
# 541905     581587_22899
# 541906     581587_23254
# 541907     581587_23255
# 541908     581587_22138
# Length: 541909, dtype: object

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# ▶ 새롭게 정의할 UID에 apply(lambda x :) 구문을 사용하여 두개의 데이터를 병합 진행
# 병합시에는 '_'.join(x) 명령어를 사용
df['UID'] = df[['InvoiceNo', 'StockCode']].apply(lambda x: '_'.join(x), axis=1)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country            UID
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  536365_85123A
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   536365_71053
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  536365_84406B
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  536365_84029G
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  536365_84029E

# %% [markdown]
# # **29. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정 조건을 활용하여 구분자 만들기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 특정 조건을 활용하여 구분자를 생성하시오**
#
# > **출력형태**
#
# ```
# * Quantity가 100 이상일시 'buy_type'이라는 컬럼을 생성하고, 'bulk'라는 값을 부여
# * 100 미만일 때는 'normal' 값을 부여
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ np.where 구문을 사용하여 Quantity가 100 이상이면 bulk 그렇지 않으면 normal을 부여 
df['buy_type'] = np.where(df['Quantity'] >=100, 'bulk', 'normal')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country buy_type
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   normal
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   normal
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom   normal
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   normal
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   normal

# %% [markdown]
# # **30. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅교집합 활용 문제**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, np.intersect1d(교집합) 명령어를 활용하여, 조건에 만족하는 값을 출력하시오**
#
# > **출력형태**
#
# ```
# * CustomerID가 17841, 14911인 두 명의 고객이 모두 구매한 물건의 List를 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df['CustomerID'].value_counts()
# Out:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
# ▶ 17841 고객과 14911 고객을 각각 df1과 df2에 할당
df1 = df[df['CustomerID'] == 17841.0]
df2 = df[df['CustomerID'] == 14911.0]

# %%
# ▶ np.intersect1d 명령어를 사용하여 교차 구매한 품목을 출력할 수 있음
np.intersect1d(df1['Description'], df2['Description'])
# Out:
# array([' DOLLY GIRL BEAKER', ' TRELLIS COAT RACK',
#        '12 DAISY PEGS IN WOOD BOX', '12 EGG HOUSE PAINTED WOOD',
#        '12 MESSAGE CARDS WITH ENVELOPES', '12 PENCIL SMALL TUBE WOODLAND',
#        '12 PENCILS SMALL TUBE RED RETROSPOT',
#        '12 PENCILS TALL TUBE RED RETROSPOT',
#        '12 PENCILS TALL TUBE SKULLS', '12 PINK HEN+CHICKS IN BASKET',
#        '16 PIECE CUTLERY SET PANTRY DESIGN',
#        '3 DRAWER ANTIQUE WHITE WOOD CABINET',
#        '3 HOOK HANGER MAGIC GARDEN', '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#        '3 PIECE SPACEBOY COOKIE CUTTER SET', '3 STRIPEY MICE FELTCRAFT',
#        '3 TIER CAKE TIN GREEN AND CREAM', '3 TIER CAKE TIN RED AND CREAM',
#        '3 TRADITIONAl BISCUIT CUTTERS  SET', '36 FOIL HEART CAKE CASES',
#        '36 FOIL STAR CAKE CASES ', '36 PENCILS TUBE RED RETROSPOT',
#        '36 PENCILS TUBE SKULLS', '3D CHRISTMAS STAMPS STICKERS ',
#        '4 IVORY DINNER CANDLES SILVER FLOCK',
#        '4 PINK DINNER CANDLE SILVER FLOCK', '6 EGG HOUSE PAINTED WOOD',
#        '6 RIBBONS RUSTIC CHARM', '6 ROCKET BALLOONS ',
#        '60 TEATIME FAIRY CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES',
#        'ABC TREASURE BOOK BOX ', 'ACRYLIC JEWEL SNOWFLAKE, PINK',
#        'ADULT APRON APPLE DELIGHT', 'ADVENT CALENDAR GINGHAM SACK',
#        'AIRLINE BAG VINTAGE JET SET BROWN',
#        'AIRLINE BAG VINTAGE JET SET RED',
#        'AIRLINE BAG VINTAGE JET SET WHITE',
#        'AIRLINE BAG VINTAGE TOKYO 78',
#        'AIRLINE BAG VINTAGE WORLD CHAMPION ',
#        'ALARM CLOCK BAKELIKE CHOCOLATE', 'ALARM CLOCK BAKELIKE GREEN',
#        'ALARM CLOCK BAKELIKE IVORY', 'ALARM CLOCK BAKELIKE ORANGE',
#        'ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED ',
#        'ALUMINIUM STAMPED HEART', 'ANTIQUE CREAM CUTLERY CUPBOARD',
#        'ANTIQUE IVORY WIRE BOWL SMALL', 'ANTIQUE SILVER T-LIGHT GLASS',
#        'APPLE BATH SPONGE', 'APRON APPLE DELIGHT',
#        'AREA PATROLLED METAL SIGN', 'ART LIGHTS,FUNK MONKEY',
#        'ASSORTED COLOUR MINI CASES', 'ASSORTED TUTTI FRUTTI PEN',
#        'ASSORTED TUTTI FRUTTI SMALL PURSE',
#        'ASSTD FRUIT+FLOWERS FRIDGE MAGNETS', 'BAG 125g SWIRLY MARBLES',
#        'BAG 250g SWIRLY MARBLES', 'BAKING MOULD CHOCOLATE CUPCAKES',
#        'BAKING MOULD HEART WHITE CHOCOLATE',
#        'BAKING MOULD ROSE WHITE CHOCOLATE',
#        'BAKING MOULD TOFFEE CUP CHOCOLATE', 'BAKING SET SPACEBOY DESIGN',
#        'BALLOON ART MAKE YOUR OWN FLOWERS', 'BASKET OF TOADSTOOLS',
#        'BATH BUILDING BLOCK WORD', 'BATHROOM METAL SIGN',
#        'BATHROOM SET LOVE HEART DESIGN', 'BELLE JARDINIERE CUSHION COVER',
#        'BEWARE OF THE CAT METAL SIGN ', 'BINGO SET',
#        'BIRD HOUSE HOT WATER BOTTLE',
#        'BIRDCAGE DECORATION TEALIGHT HOLDER', 'BIRDHOUSE GARDEN MARKER ',
#        'BISCUIT TIN VINTAGE GREEN', 'BISCUIT TIN VINTAGE RED',
#        'BISCUITS SMALL BOWL LIGHT BLUE', 'BLACK CHRISTMAS TREE 60CM',
#        'BLACK SILOUETTE CANDLE PLATE', 'BLACK TEA TOWEL CLASSIC DESIGN',
#        'BLACK/BLUE POLKADOT UMBRELLA',
#        'BLUE CHARLIE+LOLA PERSONAL DOORSIGN',
#        'BLUE COAT RACK PARIS FASHION',
#        'BLUE DRAWER KNOB ACRYLIC EDWARDIAN',
#        'BLUE HAPPY BIRTHDAY BUNTING', 'BLUE OWL SOFT TOY',
#        'BLUE PAISLEY TISSUE BOX', 'BLUE PARTY BAGS ',
#        'BLUE POLKADOT BOWL', 'BLUE POLKADOT WASHING UP GLOVES',
#        'BLUE POLKADOT WRAP', 'BLUE SPOT CERAMIC DRAWER KNOB',
#        'BLUE STRIPE CERAMIC DRAWER KNOB', 'BLUE VINTAGE SPOT BEAKER',
#        'BOOM BOX SPEAKER BOYS', 'BOTANICAL LAVENDER GIFT WRAP ',
#        'BOX OF 24 COCKTAIL PARASOLS', "BOX OF 6 MINI 50'S CRACKERS",
#        'BOX OF 6 MINI VINTAGE CRACKERS', 'BOX OF VINTAGE JIGSAW BLOCKS ',
#        'BREAD BIN DINER STYLE IVORY', 'BREAD BIN DINER STYLE PINK',
#        'BRIGHT BLUES RIBBONS ', 'BROCANTE COAT RACK',
#        'BROCANTE SHELF WITH HOOKS', 'BUFFALO BILL TREASURE BOOK BOX',
#        'BULL DOG BOTTLE OPENER', 'BUNDLE OF 3 ALPHABET EXERCISE BOOKS',
#        'BUNDLE OF 3 RETRO NOTE BOOKS', 'CAKE STAND 3 TIER MAGIC GARDEN',
#        'CAKE STAND LOVEBIRD 2 TIER PINK',
#        'CAKE STAND LOVEBIRD 2 TIER WHITE',
#        'CAKE STAND WHITE TWO TIER LACE', 'CALENDAR PAPER CUT DESIGN',
#        'CANDLE PLATE LACE WHITE', 'CANDLEHOLDER PINK HANGING HEART',
#        'CANDY HEART HANGING DECORATION', 'CARD DOLLY GIRL ',
#        'CARD GINGHAM ROSE ', 'CARDHOLDER GINGHAM STAR',
#        'CARDHOLDER HOLLY WREATH METAL', 'CERAMIC CHERRY CAKE MONEY BANK',
#        'CERAMIC PIRATE CHEST MONEY BANK',
#        'CHARLIE + LOLA RED HOT WATER BOTTLE',
#        'CHARLIE AND LOLA FIGURES TINS',
#        'CHARLIE+LOLA PINK HOT WATER BOTTLE',
#        'CHARLIE+LOLA RED HOT WATER BOTTLE ',
#        'CHARLIE+LOLA"EXTREMELY BUSY" SIGN', 'CHARLOTTE BAG APPLES DESIGN',
#        'CHARLOTTE BAG PINK POLKADOT', 'CHARLOTTE BAG SUKI DESIGN',
#        'CHARLOTTE BAG VINTAGE ALPHABET ', 'CHERUB HEART DECORATION GOLD',
#        'CHERUB HEART DECORATION SILVER ',
#        'CHEST OF DRAWERS GINGHAM HEART ', 'CHICK GREY HOT WATER BOTTLE',
#        'CHILDRENS CUTLERY POLKADOT BLUE',
#        'CHILDRENS CUTLERY POLKADOT GREEN ',
#        'CHILDRENS CUTLERY POLKADOT PINK',
#        'CHILDRENS CUTLERY RETROSPOT RED ',
#        'CHILDRENS TOY COOKING UTENSIL SET', 'CHILDS GARDEN FORK BLUE ',
#        'CHILDS GARDEN FORK PINK', 'CHILDS GARDEN RAKE BLUE',
#        'CHILDS GARDEN RAKE PINK', 'CHILDS GARDEN SPADE BLUE',
#        'CHILDS GARDEN SPADE PINK', 'CHILDS GARDEN TROWEL BLUE ',
#        'CHILLI LIGHTS', 'CHOCOLATE HOT WATER BOTTLE',
#        'CHOCOLATE THIS WAY METAL SIGN', 'CHRISTMAS CRAFT LITTLE FRIENDS',
#        'CHRISTMAS CRAFT WHITE FAIRY ', 'CHRISTMAS GINGHAM STAR',
#        'CHRISTMAS GINGHAM TREE', 'CHRISTMAS HANGING STAR WITH BELL',
#        'CHRISTMAS HANGING TREE WITH BELL', 'CHRISTMAS LIGHTS 10 REINDEER',
#        'CHRISTMAS LIGHTS 10 SANTAS ',
#        'CHRISTMAS LIGHTS 10 VINTAGE BAUBLES', 'CHRISTMAS TOILET ROLL',
#        'CHRISTMAS TREE HANGING GOLD', 'CHRISTMAS TREE PAINTED ZINC ',
#        'CIRCUS PARADE LUNCH BOX ', 'CLASSIC CAFE SUGAR DISPENSER',
#        'CLASSIC METAL BIRDCAGE PLANT HOLDER',
#        'CLEAR DRAWER KNOB ACRYLIC EDWARDIAN',
#        "CLOCK MAGNET MUM'S KITCHEN", 'CLOTHES PEGS RETROSPOT PACK 24 ',
#        'COTTON APRON PANTRY DESIGN', 'CREAM CUPID HEARTS COAT HANGER',
#        'CREAM FELT EASTER EGG BASKET', 'CREAM HEART CARD HOLDER',
#        'CREAM WALL PLANTER HEART SHAPED',
#        'DAIRY MAID TRADITIONAL TEAPOT ', 'DAISY GARDEN MARKER',
#        'DANISH ROSE ROUND SEWING BOX', 'DARK BIRD HOUSE TREE DECORATION',
#        'DECORATION WHITE CHICK MAGIC GARDEN',
#        'DECORATIVE VINTAGE COFFEE  BOX', 'DECORATIVE WICKER HEART MEDIUM',
#        'DECROTIVEVINTAGE COFFEE GRINDER BOX', 'DELUXE SEWING KIT ',
#        'DINOSAUR KEYRINGS ASSORTED', 'DINOSAUR LUNCH BOX WITH CUTLERY',
#        'DISCO BALL CHRISTMAS DECORATION', "DOCTOR'S BAG SOFT TOY",
#        'DOG BOWL VINTAGE CREAM', 'DOILEY STORAGE TIN',
#        'DOLLY GIRL CHILDRENS BOWL', 'DOLLY GIRL CHILDRENS CUP',
#        'DOLLY GIRL LUNCH BOX', 'DOLLY GIRL MINI BACKPACK',
#        'DOORMAT 3 SMILEY CATS', 'DOORMAT ENGLISH ROSE ',
#        'DOORMAT FAIRY CAKE', 'DOORMAT FANCY FONT HOME SWEET HOME',
#        'DOORMAT HEARTS', 'DOORMAT HOME SWEET HOME BLUE ',
#        'DOORMAT KEEP CALM AND COME IN', 'DOORMAT MULTICOLOUR STRIPE',
#        'DOORMAT NEW ENGLAND', 'DOORMAT RED RETROSPOT',
#        'DOORMAT RESPECTABLE HOUSE', 'DOORMAT SPOTTY HOME SWEET HOME',
#        'DOORMAT TOPIARY', 'DOORMAT WELCOME PUPPIES',
#        'DOORMAT WELCOME TO OUR HOME', 'DOORSTOP RETROSPOT HEART',
#        'DOUGHNUT LIP GLOSS ', 'DRAWER KNOB CERAMIC IVORY',
#        'DRAWER KNOB CRACKLE GLAZE BLUE',
#        'DRAWER KNOB CRACKLE GLAZE GREEN',
#        'DRAWER KNOB CRACKLE GLAZE IVORY',
#        'DRAWER KNOB CRACKLE GLAZE PINK',
#        'EAU DE NILE JEWELLED PHOTOFRAME', 'EDWARDIAN PARASOL BLACK',
#        'EDWARDIAN PARASOL NATURAL', 'EDWARDIAN PARASOL RED',
#        'EGG CUP NATURAL CHICKEN', 'EGG FRYING PAN BLUE ',
#        'EGG FRYING PAN IVORY ', 'EGG FRYING PAN MINT ',
#        'EGG FRYING PAN PINK ', 'EGG FRYING PAN RED ',
#        'EMERGENCY FIRST AID TIN ', 'ENAMEL BREAD BIN CREAM',
#        'ENAMEL COLANDER CREAM', 'ENAMEL FIRE BUCKET CREAM',
#        'ENAMEL FLOWER JUG CREAM', 'ENAMEL MEASURING JUG CREAM',
#        'ENAMEL WATERING CAN CREAM', 'ENCHANTED BIRD COATHANGER 5 HOOK',
#        'ENCHANTED BIRD PLANT CAGE', 'ENGLISH ROSE HOT WATER BOTTLE',
#        'ENGLISH ROSE NOTEBOOK A7 SIZE', 'ENGLISH ROSE SPIRIT LEVEL ',
#        'ENVELOPE 50 BLOSSOM IMAGES', 'EUCALYPTUS & PINECONE  WREATH',
#        'FAIRY CAKE DESIGN UMBRELLA', 'FAIRY SOAP SOAP HOLDER',
#        'FAMILY ALBUM WHITE PICTURE FRAME', 'FAWN BLUE HOT WATER BOTTLE',
#        'FEATHER PEN,COAL BLACK', 'FELT TOADSTOOL LARGE',
#        'FELTCRAFT 6 FLOWER FRIENDS', 'FELTCRAFT BOY JEAN-PAUL KIT',
#        'FELTCRAFT BUTTERFLY HEARTS', 'FELTCRAFT CUSHION BUTTERFLY',
#        'FELTCRAFT CUSHION OWL', 'FELTCRAFT CUSHION RABBIT',
#        'FELTCRAFT DOLL EMILY', 'FELTCRAFT DOLL MOLLY',
#        'FELTCRAFT DOLL ROSIE', 'FELTCRAFT GIRL AMELIE KIT',
#        'FELTCRAFT GIRL NICOLE KIT', 'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#        'FELTCRAFT PRINCESS LOLA DOLL', 'FELTCRAFT PRINCESS OLIVIA DOLL',
#        'FILIGREE HEART BUTTERFLY WHITE ', 'FILIGREE HEART DAISY WHITE',
#        'FIRST CLASS LUGGAGE TAG ', 'FIVE CATS HANGING DECORATION',
#        'FIVE HEART HANGING DECORATION', 'FLORAL SOFT CAR TOY',
#        'FLOWERS TILE COASTER', 'FOLDING BUTTERFLY MIRROR HOT PINK ',
#        'FOLDING BUTTERFLY MIRROR IVORY ',
#        'FOLDING BUTTERFLY MIRROR RED  ',
#        'FOLKART STAR CHRISTMAS DECORATIONS',
#        'FOOD CONTAINER SET 3 LOVE HEART ', 'FOOD COVER WITH BEADS SET 2 ',
#        'FOOT STOOL HOME SWEET HOME ', 'FRENCH BATHROOM SIGN BLUE METAL',
#        'FRENCH ENAMEL CANDLEHOLDER', 'FRENCH ENAMEL POT W LID',
#        'FRENCH ENAMEL WATER BASIN', 'FRENCH KITCHEN SIGN BLUE METAL',
#        'FRENCH LAUNDRY SIGN BLUE METAL', 'FRENCH WC SIGN BLUE METAL',
#        'FRIDGE MAGNETS US DINER ASSORTED', 'FRYING PAN PINK POLKADOT',
#        'FRYING PAN RED RETROSPOT', 'GARDENERS KNEELING PAD CUP OF TEA ',
#        'GARDENERS KNEELING PAD KEEP CALM ', 'GARLAND WOODEN HAPPY EASTER',
#        'GENTLEMAN SHIRT REPAIR KIT ', 'GEORGIAN TRINKET BOX',
#        "GIANT 50'S CHRISTMAS CRACKER", 'GIN + TONIC DIET METAL SIGN',
#        'GINGERBREAD MAN COOKIE CUTTER', 'GINGHAM HEART DECORATION',
#        'GINGHAM RECIPE BOOK BOX', 'GIRAFFE WOODEN RULER',
#        'GIRLS VINTAGE TIN SEASIDE BUCKET', 'GLITTER BUTTERFLY CLIPS',
#        'GLITTER CHRISTMAS STAR ', 'GLITTER CHRISTMAS TREE WITH BELLS',
#        'GLITTER HANGING BUTTERFLY STRING', 'GLITTER HEART DECORATION',
#        'GOLD MINI TAPE MEASURE ', 'GOLD PHOTO FRAME',
#        'GRAND CHOCOLATECANDLE', 'GREEN DRAWER KNOB ACRYLIC EDWARDIAN',
#        'GREEN EASTER EGG HUNT START POST',
#        'GREEN GOOSE FEATHER TREE 60CM', 'GREEN METAL BOX ARMY SUPPLIES',
#        'GREEN ROSE WASHBAG', 'GREEN VINTAGE SPOT BEAKER',
#        'GREY HEART HOT WATER BOTTLE', 'GUMBALL COAT RACK',
#        'GUMBALL MAGAZINE RACK', 'GYMKHANA TREASURE BOOK BOX',
#        'HAND OVER THE CHOCOLATE   SIGN ', 'HAND WARMER RED RETROSPOT',
#        'HAND WARMER SCOTTY DOG DESIGN', 'HANGING HEART BONHEUR',
#        'HANGING HEART WITH BELL', 'HANGING HEART ZINC T-LIGHT HOLDER',
#        'HANGING METAL HEART LANTERN', 'HANGING METAL STAR LANTERN',
#        'HANGING PHOTO CLIP ROPE LADDER',
#        'HANGING QUILTED PATCHWORK APPLES', 'HAPPY STENCIL CRAFT',
#        'HEADS AND TAILS SPORTING FUN', 'HEART BEADED TRELLIS DECORATION',
#        'HEART DECORATION RUSTIC HANGING ', 'HEART FILIGREE DOVE  SMALL',
#        'HEART IVORY TRELLIS SMALL', 'HEART OF WICKER LARGE',
#        'HEART OF WICKER SMALL', 'HEART WOODEN CHRISTMAS DECORATION',
#        'HEART WREATH DECORATION WITH BELL',
#        'HELLO SAILOR BLUE SOAP HOLDER',
#        'HEN HOUSE W FAMILY IN BARN & NEST', 'HERB MARKER BASIL',
#        'HERB MARKER CHIVES ', 'HERB MARKER MINT', 'HERB MARKER PARSLEY',
#        'HERB MARKER ROSEMARY', 'HERB MARKER THYME', 'HOLIDAY FUN LUDO',
#        'HOME BUILDING BLOCK WORD', 'HOME GARLAND PAINTED ZINC ',
#        'HOME SMALL WOOD LETTERS', 'HOME SWEET HOME 2 DRAWER CABINET',
#        'HOME SWEET HOME 3 PEG HANGER ', 'HOME SWEET HOME BLACKBOARD',
#        'HOME SWEET HOME CUSHION COVER ', 'HOME SWEET HOME HANGING HEART',
#        'HOME SWEET HOME KEY HOLDER', 'HOME SWEET HOME METAL SIGN ',
#        'HOME SWEET HOME MUG', 'HOMEMADE JAM SCENTED CANDLES',
#        'HOT BATHS METAL SIGN', 'HOT WATER BOTTLE BABUSHKA ',
#        'HOT WATER BOTTLE I AM SO POORLY', 'HOT WATER BOTTLE KEEP CALM',
#        'HOT WATER BOTTLE TEA AND SYMPATHY', "I'M ON HOLIDAY METAL SIGN",
#        'ILLUSTRATED CAT BOWL ', 'IVORY DINER WALL CLOCK',
#        'IVORY HANGING DECORATION  BIRD', 'IVORY KNITTED MUG COSY ',
#        'IVORY REFECTORY CLOCK', 'IVORY SWEETHEART SOAP DISH',
#        'IVORY SWEETHEART WIRE LETTER RACK ', 'IVORY WICKER HEART LARGE',
#        'IVORY WICKER HEART MEDIUM', 'IVORY WIRE KITCHEN ORGANISER',
#        'IVORY WIRE SWEETHEART LETTER TRAY', 'JAM CLOCK MAGNET',
#        'JAM JAR WITH PINK LID', 'JAM MAKING SET PRINTED',
#        'JAM MAKING SET WITH JARS', 'JAZZ HEARTS ADDRESS BOOK',
#        'JAZZ HEARTS PURSE NOTEBOOK', 'JIGSAW RABBIT AND BIRDHOUSE',
#        'JINGLE BELL HEART ANTIQUE GOLD', 'JINGLE BELL HEART DECORATION',
#        'JUMBO  BAG BAROQUE BLACK WHITE', 'JUMBO BAG ALPHABET',
#        'JUMBO BAG APPLES', 'JUMBO BAG DOILEY PATTERNS', 'JUMBO BAG OWLS',
#        'JUMBO BAG PAISLEY PARK', 'JUMBO BAG PEARS',
#        'JUMBO BAG PINK POLKADOT', 'JUMBO BAG PINK VINTAGE PAISLEY',
#        'JUMBO BAG RED RETROSPOT', 'JUMBO BAG SPACEBOY DESIGN',
#        'JUMBO BAG STRAWBERRY', 'JUMBO BAG VINTAGE DOILY ',
#        'JUMBO BAG VINTAGE LEAF', 'JUMBO BAG WOODLAND ANIMALS',
#        'JUMBO SHOPPER VINTAGE RED PAISLEY',
#        'JUNGLE POPSICLES ICE LOLLY MOULDS', 'KEY CABINET MA CAMPAGNE',
#        'KEY FOB , BACK DOOR ', 'KEY FOB , FRONT  DOOR ',
#        'KEY FOB , GARAGE DESIGN', 'KEY FOB , SHED',
#        'KEY RING BASEBALL BOOT ASSORTED ',
#        'KITCHEN FLOWER POTS WALL PLAQUE',
#        'KNEELING MAT HOUSEWORK  DESIGN', 'LANTERN CREAM GAZEBO ',
#        'LARGE CAKE STAND  HANGING STRAWBERY',
#        'LARGE CERAMIC TOP STORAGE JAR', 'LARGE CHINESE STYLE SCISSOR',
#        'LARGE HANGING IVORY & RED WOOD BIRD',
#        'LARGE HEART MEASURING SPOONS', 'LARGE IVORY HEART WALL ORGANISER',
#        'LARGE PURPLE BABUSHKA NOTEBOOK  ', 'LARGE RED BABUSHKA NOTEBOOK ',
#        'LARGE WHITE HEART OF WICKER', 'LARGE YELLOW BABUSHKA NOTEBOOK ',
#        'LAUREL STAR ANTIQUE GOLD', 'LAVENDER SCENTED FABRIC HEART',
#        'LE GRAND TRAY CHIC SET', 'LETTER HOLDER HOME SWEET HOME',
#        'LOLITA  DESIGN  COTTON TOTE BAG', 'LOVE BUILDING BLOCK WORD',
#        'LOVE GARLAND PAINTED ZINC ', 'LOVE HEART SOCK HANGER',
#        'LOVE HEART TRINKET POT', 'LOVE HOT WATER BOTTLE',
#        'LOVEBIRD HANGING DECORATION WHITE ', 'LUNCH BAG  BLACK SKULL.',
#        'LUNCH BAG ALPHABET DESIGN', 'LUNCH BAG APPLE DESIGN',
#        'LUNCH BAG CARS BLUE', 'LUNCH BAG DOILEY PATTERN ',
#        'LUNCH BAG DOLLY GIRL DESIGN', 'LUNCH BAG PAISLEY PARK  ',
#        'LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT',
#        'LUNCH BAG SPACEBOY DESIGN ', 'LUNCH BAG SUKI DESIGN ',
#        'LUNCH BAG VINTAGE DOILY ', 'LUNCH BAG VINTAGE LEAF DESIGN',
#        'LUNCH BAG WOODLAND', 'LUNCH BOX WITH CUTLERY RETROSPOT ',
#        'MA CAMPAGNE CUTLERY BOX', 'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#        'MAKE YOUR OWN MONSOON CARD KIT',
#        'MAKE YOUR OWN PLAYTIME CARD KIT', 'MEASURING TAPE BABUSHKA BLUE',
#        'MEASURING TAPE BABUSHKA PINK', 'MEDIUM CERAMIC TOP STORAGE JAR',
#        'MEMO BOARD COTTAGE DESIGN', 'MEMO BOARD RETROSPOT  DESIGN',
#        'METAL 4 HOOK HANGER FRENCH CHATEAU', 'METAL SIGN DROP YOUR PANTS',
#        'METAL SIGN TAKE IT OR LEAVE IT ',
#        'METAL SIGN,CUPCAKE SINGLE HOOK', 'MILK PAN BLUE POLKADOT',
#        'MILK PAN RED RETROSPOT', 'MINI WOODEN HAPPY BIRTHDAY GARLAND',
#        'MINIATURE ANTIQUE ROSE HOOK IVORY',
#        'MISTLETOE HEART WREATH CREAM', 'MOBILE VINTAGE HEARTS ',
#        'MONEY BOX HOUSEKEEPING DESIGN', 'MONEY BOX POCKET MONEY DESIGN',
#        "MOTHER'S KITCHEN SPOON REST ", 'MOUSE TOY WITH PINK T-SHIRT',
#        'MR ROBOT SOFT TOY', "MUM'S KITCHEN CLOCK", 'Manual',
#        'NATURAL SLATE CHALKBOARD LARGE ',
#        'NATURAL SLATE HEART CHALKBOARD ',
#        'NATURAL SLATE RECTANGLE CHALKBOARD', 'NEW BAROQUE JEWELLERY BOX ',
#        'NO JUNK MAIL METAL SIGN', 'NO SINGING METAL SIGN',
#        'NOEL GARLAND PAINTED ZINC ', 'NOEL WOODEN BLOCK LETTERS ',
#        'NOVELTY BISCUITS CAKE STAND 3 TIER',
#        'NURSERY A,B,C PAINTED LETTERS', 'OPEN CLOSED METAL SIGN',
#        'OVEN MITT APPLES DESIGN', 'OVERNIGHT BAG VINTAGE ROSE PAISLEY',
#        'PACK OF 12 BLUE PAISLEY TISSUES ',
#        'PACK OF 12 HEARTS DESIGN TISSUES ',
#        'PACK OF 12 PAISLEY PARK TISSUES ',
#        'PACK OF 12 PINK PAISLEY TISSUES ',
#        'PACK OF 12 PINK POLKADOT TISSUES',
#        'PACK OF 12 RED RETROSPOT TISSUES ', 'PACK OF 12 SKULL TISSUES',
#        'PACK OF 12 SPACEBOY TISSUES', 'PACK OF 12 SUKI TISSUES ',
#        'PACK OF 12 WOODLAND TISSUES ', 'PACK OF 20 NAPKINS PANTRY DESIGN',
#        'PACK OF 20 NAPKINS RED APPLES', 'PACK OF 60 DINOSAUR CAKE CASES',
#        'PACK OF 60 MUSHROOM CAKE CASES',
#        'PACK OF 60 PINK PAISLEY CAKE CASES',
#        'PACK OF 60 SPACEBOY CAKE CASES',
#        'PACK OF 72 RETROSPOT CAKE CASES', 'PACK OF 72 SKULL CAKE CASES',
#        'PAINTED METAL PEARS ASSORTED', 'PANTRY APPLE CORER',
#        'PANTRY MAGNETIC  SHOPPING LIST', 'PANTRY PASTRY BRUSH',
#        'PANTRY ROLLING PIN', 'PANTRY SCRUBBING BRUSH',
#        'PANTRY WASHING UP BRUSH', 'PAPER BUNTING COLOURED LACE',
#        'PAPER BUNTING RETROSPOT', 'PAPER BUNTING VINTAGE PAISLEY',
#        'PAPER BUNTING WHITE LACE', "PAPER CHAIN KIT 50'S CHRISTMAS ",
#        'PAPER CHAIN KIT VINTAGE CHRISTMAS', 'PAPERWEIGHT VINTAGE PAISLEY',
#        'PARISIENNE CURIO CABINET', 'PARISIENNE JEWELLERY DRAWER ',
#        'PARISIENNE KEY CABINET ', 'PARISIENNE SEWING BOX',
#        'PARTY BUNTING', 'PARTY INVITES JAZZ HEARTS',
#        'PARTY INVITES WOODLAND', 'PARTY METAL SIGN ',
#        'PARTY PIZZA DISH RED RETROSPOT', 'PEG BAG APPLES DESIGN',
#        'PHARMACIE FIRST AID TIN', 'PHOTO CUBE',
#        'PHOTO FRAME 3 CLASSIC HANGING', 'PHOTO FRAME CORNICE',
#        'PHOTO FRAME LINEN AND LACE LARGE',
#        'PHOTO FRAME LINEN AND LACE SMALL',
#        'PICTURE FRAME WOOD TRIPLE PORTRAIT', 'PINK  POLKADOT PLATE ',
#        'PINK BLUE FELT CRAFT TRINKET BOX',
#        'PINK CREAM FELT CRAFT TRINKET BOX ', 'PINK DOUGHNUT TRINKET POT ',
#        'PINK DRAWER KNOB ACRYLIC EDWARDIAN',
#        'PINK FAIRY CAKE CHILDRENS APRON',
#        'PINK FLORAL FELTCRAFT SHOULDER BAG',
#        'PINK GINGHAM CAT WITH SCARF', 'PINK HAPPY BIRTHDAY BUNTING',
#        'PINK HEART SHAPE EGG FRYING PAN', 'PINK OWL SOFT TOY',
#        'PINK PADDED MOBILE', 'PINK POLKADOT PLATE ',
#        'PINK POLKADOT WRAP ', 'PINK ROSE WASHBAG',
#        'PINK VINTAGE PAISLEY PICNIC BAG', 'PINK VINTAGE SPOT BEAKER',
#        'PLACE SETTING WHITE HEART', 'PLASTERS IN TIN CIRCUS PARADE ',
#        'PLASTERS IN TIN SKULLS', 'PLASTERS IN TIN SPACEBOY',
#        'PLASTERS IN TIN STRONGMAN', 'PLASTERS IN TIN VINTAGE PAISLEY ',
#        'PLASTERS IN TIN WOODLAND ANIMALS', 'PLEASE ONE PERSON METAL SIGN',
#        'POLYESTER FILLER PAD 30CMx30CM', 'POLYESTER FILLER PAD 45x45cm',
#        'POPART WOODEN PENCILS ASST', 'POPCORN HOLDER',
#        "POPPY'S PLAYHOUSE KITCHEN", 'POTTERING IN THE SHED METAL SIGN',
#        'POTTERING MUG', 'POTTING SHED SEED ENVELOPES',
#        'POTTING SHED TWINE', 'PURPLE DRAWERKNOB ACRYLIC EDWARDIAN',
#        'QUEEN OF SKIES LUGGAGE TAG', 'RABBIT NIGHT LIGHT',
#        'RECIPE BOX BLUE SKETCHBOOK DESIGN',
#        'RECIPE BOX PANTRY YELLOW DESIGN', 'RECIPE BOX RETROSPOT ',
#        'RECYCLED ACAPULCO MAT GREEN', 'RECYCLED ACAPULCO MAT RED',
#        'RECYCLING BAG RETROSPOT ', 'RED CHARLIE+LOLA PERSONAL DOORSIGN',
#        'RED DRAWER KNOB ACRYLIC EDWARDIAN',
#        'RED FLORAL FELTCRAFT SHOULDER BAG', 'RED GINGHAM TEDDY BEAR ',
#        'RED HANGING HEART T-LIGHT HOLDER', 'RED LOVE HEART SHAPE CUP',
#        'RED METAL BEACH SPADE ', 'RED METAL BOX TOP SECRET',
#        'RED PAPER PARASOL', 'RED RETROSPOT APRON ', 'RED RETROSPOT BOWL',
#        'RED RETROSPOT BUTTER DISH', 'RED RETROSPOT CAKE STAND',
#        'RED RETROSPOT CHARLOTTE BAG', 'RED RETROSPOT MINI CASES',
#        'RED RETROSPOT OVEN GLOVE ', 'RED RETROSPOT OVEN GLOVE DOUBLE',
#        'RED RETROSPOT PEG BAG', 'RED RETROSPOT PICNIC BAG',
#        'RED RETROSPOT PLATE ', 'RED RETROSPOT ROUND CAKE TINS',
#        'RED RETROSPOT SHOPPER BAG', 'RED RETROSPOT SMALL MILK JUG',
#        'RED RETROSPOT SUGAR JAM BOWL', 'RED RETROSPOT TISSUE BOX',
#        'RED RETROSPOT UMBRELLA', 'RED RETROSPOT WRAP ',
#        'RED ROCKING HORSE HAND PAINTED', 'RED SPOT CERAMIC DRAWER KNOB',
#        'RED SPOTTY BISCUIT TIN', 'RED STAR CARD HOLDER',
#        'RED STRIPE CERAMIC DRAWER KNOB', 'RED TOADSTOOL LED NIGHT LIGHT',
#        'RED VINTAGE SPOT BEAKER', 'RED WOOLLY HOTTIE WHITE HEART.',
#        'REGENCY CAKE SLICE', 'REGENCY CAKESTAND 3 TIER',
#        'REGENCY SUGAR TONGS', 'REGENCY TEA PLATE GREEN ',
#        'REGENCY TEA PLATE ROSES ', 'REGENCY TEA SPOON',
#        'REGENCY TEA STRAINER', 'REINDEER HEART DECORATION GOLD',
#        'REINDEER HEART DECORATION SILVER',
#        'RETROSPOT HEART HOT WATER BOTTLE', 'RETROSPOT LAMP',
#        'RETROSPOT RED WASHING UP GLOVES',
#        'RETROSPOT TEA SET CERAMIC 11 PC ', 'REVOLVER WOODEN RULER ',
#        'RIBBON REEL CHRISTMAS SOCK BAUBLE', 'RIBBON REEL LACE DESIGN ',
#        'ROCKING HORSE RED CHRISTMAS ', 'ROMANTIC PINKS RIBBONS ',
#        'ROSE COTTAGE KEEPSAKE BOX ', 'ROSE DU SUD OVEN GLOVE',
#        'ROUND CAKE TIN VINTAGE GREEN',
#        'ROUND SNACK BOXES SET OF 4 FRUITS ',
#        'ROUND SNACK BOXES SET OF 4 SKULLS',
#        'ROUND SNACK BOXES SET OF4 WOODLAND ',
#        'ROUND STORAGE TIN VINTAGE LEAF', 'RUSTIC MIRROR WITH LACE HEART',
#        'SANDWICH BATH SPONGE', 'SAVE THE PLANET COTTON TOTE BAG',
#        'SAVE THE PLANET MUG', 'SCANDINAVIAN REDS RIBBONS',
#        'SCOTTIE DOG HOT WATER BOTTLE', 'SCOTTIE DOGS BABY BIB',
#        'SCOTTIES DESIGN WASHBAG', 'SET 12 COLOUR PENCILS DOLLY GIRL ',
#        'SET 12 COLOUR PENCILS SPACEBOY ',
#        'SET 12 COLOURING PENCILS DOILY',
#        'SET 12 KIDS COLOUR  CHALK STICKS',
#        'SET 2 PANTRY DESIGN TEA TOWELS',
#        'SET 20 NAPKINS FAIRY CAKES DESIGN ',
#        'SET 3 PAPER VINTAGE CHICK PAPER EGG',
#        'SET 3 RETROSPOT TEA,COFFEE,SUGAR',
#        'SET 3 SONG BIRD PAPER EGGS ASSORTED',
#        'SET 40 HEART SHAPE PETIT FOUR CASES',
#        'SET 6 PAPER TABLE LANTERN HEARTS ',
#        'SET 6 PAPER TABLE LANTERN STARS ', 'SET 7 BABUSHKA NESTING BOXES',
#        'SET OF 10 LANTERNS FAIRY LIGHT STAR',
#        'SET OF 10 LED DOLLY LIGHTS', 'SET OF 12 FAIRY CAKE BAKING CASES',
#        'SET OF 16 VINTAGE BLACK CUTLERY',
#        'SET OF 16 VINTAGE PISTACHIO CUTLERY',
#        'SET OF 16 VINTAGE RED CUTLERY', 'SET OF 16 VINTAGE ROSE CUTLERY',
#        'SET OF 16 VINTAGE SKY BLUE CUTLERY',
#        'SET OF 2 CERAMIC CHRISTMAS TREES',
#        'SET OF 2 CERAMIC PAINTED HEARTS ',
#        'SET OF 2 TEA TOWELS APPLE AND PEARS',
#        'SET OF 2 TRAYS HOME SWEET HOME', 'SET OF 2 WOODEN MARKET CRATES',
#        'SET OF 20 KIDS COOKIE CUTTERS',
#        'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#        'SET OF 3 BIRD LIGHT PINK FEATHER ',
#        'SET OF 3 CAKE TINS PANTRY DESIGN ',
#        'SET OF 3 CAKE TINS SKETCHBOOK',
#        'SET OF 3 HANGING OWLS OLLIE BEAK',
#        'SET OF 3 HEART COOKIE CUTTERS', 'SET OF 3 REGENCY CAKE TINS',
#        'SET OF 3 WOODEN HEART DECORATIONS',
#        'SET OF 3 WOODEN SLEIGH DECORATIONS',
#        'SET OF 3 WOODEN STOCKING DECORATION',
#        'SET OF 3 WOODEN TREE DECORATIONS',
#        'SET OF 36 DINOSAUR PAPER DOILIES',
#        'SET OF 4 ENGLISH ROSE COASTERS',
#        'SET OF 4 ENGLISH ROSE PLACEMATS', 'SET OF 4 FAIRY CAKE PLACEMATS',
#        'SET OF 4 FAIRY CAKE PLACEMATS ', 'SET OF 4 JAM JAR MAGNETS',
#        'SET OF 4 KNICK KNACK TINS DOILEY ',
#        'SET OF 4 KNICK KNACK TINS DOILY ',
#        'SET OF 4 KNICK KNACK TINS LEAF', 'SET OF 4 NAPKIN CHARMS CUTLERY',
#        'SET OF 4 PANTRY JELLY MOULDS', 'SET OF 5 LUCKY CAT MAGNETS ',
#        'SET OF 5 MINI GROCERY MAGNETS', 'SET OF 5 PANCAKE DAY MAGNETS',
#        'SET OF 6 HERB TINS SKETCHBOOK', 'SET OF 6 NATIVITY MAGNETS ',
#        'SET OF 6 SNACK LOAF BAKING CASES',
#        'SET OF 6 SPICE TINS PANTRY DESIGN',
#        'SET OF 6 T-LIGHTS EASTER CHICKS', 'SET OF 6 T-LIGHTS TOADSTOOLS',
#        'SET OF 6 TEA TIME BAKING CASES',
#        'SET OF 60 PANTRY DESIGN CAKE CASES ',
#        'SET OF 60 VINTAGE LEAF CAKE CASES ',
#        'SET OF 72 PINK HEART PAPER DOILIES',
#        'SET OF 9 BLACK SKULL BALLOONS',
#        'SET OF SALT AND PEPPER TOADSTOOLS',
#        'SET OF TEA COFFEE SUGAR TINS PANTRY',
#        'SET/10 BLUE POLKADOT PARTY CANDLES',
#        'SET/10 PINK POLKADOT PARTY CANDLES',
#        'SET/10 RED POLKADOT PARTY CANDLES',
#        'SET/2 RED RETROSPOT TEA TOWELS ',
#        'SET/20 RED RETROSPOT PAPER NAPKINS ',
#        'SET/20 STRAWBERRY PAPER NAPKINS ', 'SET/4 BADGES DOGS',
#        'SET/4 SKULL BADGES', 'SET/4 SPRING FLOWER DECORATION',
#        'SET/4 WHITE RETRO STORAGE CUBES ',
#        'SET/5 RED RETROSPOT LID GLASS BOWLS',
#        'SET/6 BEAD COASTERS GAUZE BAG GOLD', 'SET/6 COLLAGE PAPER CUPS',
#        'SET/6 COLLAGE PAPER PLATES', 'SET/6 RED SPOTTY PAPER CUPS',
#        'SET/6 RED SPOTTY PAPER PLATES',
#        'SET/6 TURQUOISE BUTTERFLY T-LIGHTS',
#        'SEWING BOX RETROSPOT DESIGN ',
#        'SHELF WITH 4 HOOKS HOME SWEET HOME',
#        'SILVER BELLS TABLE DECORATION',
#        'SILVER CHRISTMAS TREE BAUBLE STAND ', 'SILVER STANDING GNOME   ',
#        'SILVER STARS TABLE DECORATION', 'SINGLE ANTIQUE ROSE HOOK IVORY',
#        'SINGLE WIRE HOOK IVORY HEART',
#        'SKETCHBOOK MAGNETIC SHOPPING LIST', 'SKULL DESIGN TV DINNER TRAY',
#        'SKULL SHOULDER BAG', 'SKULLS  STICKERS',
#        'SLATE TILE NATURAL HANGING', 'SMALL CERAMIC TOP STORAGE JAR ',
#        'SMALL CHINESE STYLE SCISSOR', 'SMALL CHOCOLATES PINK BOWL',
#        'SMALL DOLLY MIX DESIGN ORANGE BOWL',
#        'SMALL HANGING IVORY/RED WOOD BIRD',
#        'SMALL HEART MEASURING SPOONS', 'SMALL IVORY HEART WALL ORGANISER',
#        'SMALL MARSHMALLOWS PINK BOWL',
#        'SMALL PARISIENNE HEART PHOTO FRAME ',
#        'SMALL PINK MAGIC CHRISTMAS TREE',
#        'SMALL PURPLE BABUSHKA NOTEBOOK ', 'SMALL RED BABUSHKA NOTEBOOK ',
#        'SMALL WHITE HEART OF WICKER', 'SMALL YELLOW BABUSHKA NOTEBOOK ',
#        'SOAP DISH BROCANTE', 'SPACEBOY BEAKER', 'SPACEBOY BIRTHDAY CARD',
#        'SPACEBOY CHILDRENS BOWL', 'SPACEBOY CHILDRENS CUP',
#        'SPACEBOY LUNCH BOX ', 'SPACEBOY MINI BACKPACK',
#        'SPACEBOY TV DINNER TRAY', 'SPOTTY BUNTING',
#        'STAR DECORATION PAINTED ZINC ', 'STAR PORTABLE TABLE LIGHT ',
#        'STAR WOODEN CHRISTMAS DECORATION',
#        'STAR WREATH DECORATION WITH BELL', 'STOOL HOME SWEET HOME ',
#        'STORAGE TIN VINTAGE LEAF', 'STRAWBERRY BATH SPONGE ',
#        'STRAWBERRY CERAMIC TRINKET BOX', 'STRAWBERRY CERAMIC TRINKET POT',
#        'STRAWBERRY CHARLOTTE BAG', 'STRAWBERRY LUNCH BOX WITH CUTLERY',
#        'STRAWBERRY SHOPPER BAG', 'SUKI  SHOULDER BAG',
#        'SWALLOW WOODEN CHRISTMAS DECORATION',
#        'SWEETHEART 3 TIER CAKE STAND ', 'SWEETHEART CAKESTAND 3 TIER',
#        'SWEETHEART CERAMIC TRINKET BOX', 'SWEETHEART RECIPE BOOK STAND',
#        'SWEETHEART WIRE FRUIT BOWL', 'SWEETHEART WIRE MAGAZINE RACK',
#        'SWEETHEART WIRE WALL TIDY', 'SWISS ROLL TOWEL, CHOCOLATE  SPOTS',
#        'T-LIGHT HOLDER HANGING LOVE BIRD',
#        'TABLECLOTH RED APPLES DESIGN ', 'TEA BAG PLATE RED RETROSPOT',
#        'TEA COSY BLUE STRIPE', 'TEA COSY RED  STRIPE',
#        'TEA PARTY BIRTHDAY CARD', 'TEA TIME DES TEA COSY',
#        'TEA TIME KITCHEN APRON', 'TEA TIME OVEN GLOVE',
#        'TEA TIME PARTY BUNTING', 'TEA TIME TABLE CLOTH',
#        'TOADSTOOL MONEY BOX', 'TOILET METAL SIGN', 'TOOL BOX SOFT TOY ',
#        'TOXIC AREA  DOOR HANGER ', 'TOY TIDY PINK POLKADOT',
#        'TOY TIDY SPACEBOY  ', 'TRADITIONAL KNITTING NANCY',
#        'TRAVEL CARD WALLET FLOWER MEADOW', 'TRAVEL CARD WALLET PANTRY',
#        'TRAVEL CARD WALLET RETRO PETALS', 'TRAVEL CARD WALLET RETROSPOT',
#        'TRAVEL CARD WALLET TRANSPORT', 'TRAVEL SEWING KIT',
#        'TRAY, BREAKFAST IN BED', 'TREASURE ISLAND BOOK BOX',
#        'TREASURE TIN GYMKHANA DESIGN', 'TRIANGULAR POUFFE VINTAGE ',
#        'TRIPLE HOOK ANTIQUE IVORY ROSE', 'TROPICAL PASSPORT COVER ',
#        'TV DINNER TRAY DOLLY GIRL', 'TV DINNER TRAY VINTAGE PAISLEY',
#        'TWO DOOR CURIO CABINET', 'VICTORIAN GLASS HANGING T-LIGHT',
#        'VICTORIAN SEWING BOX LARGE', 'VICTORIAN SEWING BOX SMALL ',
#        'VICTORIAN SEWING KIT', 'VINTAGE  2 METER FOLDING RULER',
#        'VINTAGE BEAD PINK PURSE ', 'VINTAGE CHRISTMAS BUNTING',
#        'VINTAGE CHRISTMAS GIFT SACK', 'VINTAGE CREAM 3 BASKET CAKE STAND',
#        'VINTAGE CREAM CAT FOOD CONTAINER',
#        'VINTAGE CREAM DOG FOOD CONTAINER',
#        'VINTAGE DOILY DELUXE SEWING KIT ', 'VINTAGE DOILY JUMBO BAG RED ',
#        'VINTAGE DOILY TRAVEL SEWING KIT', 'VINTAGE EMBOSSED HEART',
#        'VINTAGE LEAF CHOPPING BOARD  ', 'VINTAGE LEAF MAGNETIC NOTEPAD',
#        'VINTAGE SNAKES & LADDERS', 'VINTAGE SNAP CARDS',
#        'VIPPASSPORT COVER ', 'WAKE UP COCKEREL TILE COASTER',
#        'WALL ART DOG LICENCE ', 'WASHROOM METAL SIGN',
#        'WATERING CAN BLUE ELEPHANT', 'WATERING CAN GARDEN MARKER',
#        'WATERING CAN GREEN DINOSAUR', 'WATERING CAN PINK BUNNY',
#        'WELCOME  WOODEN BLOCK LETTERS', 'WHITE BAROQUE WALL CLOCK ',
#        'WHITE BROCANTE SOAP DISH', 'WHITE GOOSE FEATHER CHRISTMAS TREE ',
#        'WHITE GOOSE FEATHER TREE 60CM ',
#        'WHITE HANGING HEART T-LIGHT HOLDER',
#        'WHITE HEART CONFETTI IN TUBE',
#        'WHITE HEARTS WIRE PLANT POT HOLDER', 'WHITE METAL LANTERN',
#        'WHITE ROCKING HORSE HAND PAINTED',
#        'WHITE SKULL HOT WATER BOTTLE ',
#        'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#        'WHITE SPOT RED CERAMIC DRAWER KNOB', 'WHITE WICKER STAR ',
#        'WHITE WIRE EGG HOLDER', 'WHITE WOOD GARDEN PLANT LADDER',
#        'WICKER STAR ', 'WICKER WREATH LARGE',
#        'WOOD 2 DRAWER CABINET WHITE FINISH',
#        'WOOD BLACK BOARD ANT WHITE FINISH', 'WOOD STAMP SET BEST WISHES',
#        'WOOD STAMP SET FLOWERS', 'WOOD STAMP SET HAPPY BIRTHDAY',
#        'WOOD STAMP SET THANK YOU', 'WOOD STOCKING CHRISTMAS SCANDISPOT',
#        'WOODEN ADVENT CALENDAR CREAM', 'WOODEN ADVENT CALENDAR RED',
#        'WOODEN BOX OF DOMINOES', 'WOODEN FRAME ANTIQUE WHITE ',
#        'WOODEN HAPPY BIRTHDAY GARLAND',
#        'WOODEN HEART CHRISTMAS SCANDINAVIAN',
#        'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN SCHOOL COLOURING SET',
#        'WOODEN STAR CHRISTMAS SCANDINAVIAN',
#        'WOODEN TREE CHRISTMAS SCANDINAVIAN', 'WOODLAND CHARLOTTE BAG',
#        "WRAP 50'S  CHRISTMAS", 'WRAP ALPHABET DESIGN',
#        'WRAP CHRISTMAS VILLAGE', 'WRAP ENGLISH ROSE ',
#        'WRAP GREEN PEARS ', 'WRAP PINK FAIRY CAKES ', 'WRAP RED APPLES ',
#        'WRAP VINTAGE LEAF DESIGN', 'WRAP VINTAGE PETALS  DESIGN',
#        'YELLOW EASTER EGG HUNT START POST', 'ZINC FOLKART SLEIGH BELLS',
#        'ZINC HEART FLOWER T-LIGHT HOLDER', 'ZINC METAL HEART DECORATION',
#        'ZINC SWEETHEART WIRE LETTER RACK',
#        'ZINC T-LIGHT HOLDER STAR LARGE',
#        'ZINC T-LIGHT HOLDER STARS SMALL',
#        'ZINC WIRE SWEETHEART LETTER TRAY'], dtype=object)

# %% [markdown]
# # **31. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅데이터 합치기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,concat 명령어를 활용하여 데이터를 합치시오**
#
# > **출력형태**
#
# ```
# * 국가가 United Kigndom과 Spain에 해당하는 데이터를 각각 df1, df2로 추출
# * df1, df2를 concat을 통해 합치고, 하나의 데이터프레임 생성
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 국가 확인 
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
# ▶ 각 국가별 데이터프레임 할당
df1 = df[df['Country'] == 'United Kingdom']
df2 = df[df['Country'] == 'Spain']

# %%
# ▶ 다시 병합 
df3 = pd.concat([df1,df2], axis=0)
df3.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df3['Country'].value_counts()
# Out:
# United Kingdom    495478
# Spain               2533
# Name: Country, dtype: int64

# %% [markdown]
# # **32. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅결측치가 하나라도 있는 행 찾기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 조건에 만족하는 행을 출력하시오**
#
# > **출력형태**
#
# ```
# * any 명령어를 활용하여, NA 값이 1개라도 있는 행을 모두 출력할 것
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ .any(axis=1)명령어를 통해 모든 컬럼에 하나라도 NA값이 있는 행을 출력할 수 있음
df[df.isnull().any(axis=1)]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 622     12/1/2010 11:52       0.00         NaN  United Kingdom
# 1443    12/1/2010 14:32       2.51         NaN  United Kingdom
# 1444    12/1/2010 14:32       2.51         NaN  United Kingdom
# 1445    12/1/2010 14:32       0.85         NaN  United Kingdom
# 1446    12/1/2010 14:32       1.66         NaN  United Kingdom
# ...                 ...        ...         ...             ...
# 541536  12/9/2011 10:26       4.13         NaN  United Kingdom
# 541537  12/9/2011 10:26       4.13         NaN  United Kingdom
# 541538  12/9/2011 10:26       4.96         NaN  United Kingdom
# 541539  12/9/2011 10:26      10.79         NaN  United Kingdom
# 541540  12/9/2011 10:26    1714.17         NaN  United Kingdom
#
# [135080 rows x 8 columns]

# %%
df.isnull().any(axis=1).sum()
# Out:
# 135080

# %%
df.isnull().any(axis=0).sum()
# Out:
# 2

# %%
df.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
df.isnull().any(axis=0)
# Out:
# InvoiceNo      False
# StockCode      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID      True
# Country        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
len(df[df.isnull().any(axis=1)])
# Out:
# 135080

# %%
df.count()
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %%
df.value_counts()
# Out:
# InvoiceNo  StockCode  Description                          Quantity  InvoiceDate       UnitPrice  CustomerID  Country
# 555524     22698      PINK REGENCY TEACUP AND SAUCER        1        6/5/2011 11:37    2.95       16923.0     United Kingdom    20
#            22697      GREEN REGENCY TEACUP AND SAUCER       1        6/5/2011 11:37    2.95       16923.0     United Kingdom    12
# 572861     22775      PURPLE DRAWERKNOB ACRYLIC EDWARDIAN   12       10/26/2011 12:46  1.25       14102.0     United Kingdom     8
# 572344     M          Manual                                48       10/24/2011 10:43  1.50       14607.0     United Kingdom     6
# 578289     23395      BELLE JARDINIERE CUSHION COVER        1        11/23/2011 14:07  3.75       17841.0     United Kingdom     6
#                                                                                                                                 ..
# 553915     21174      POTTERING IN THE SHED METAL SIGN      12       5/19/2011 19:51   2.08       18225.0     United Kingdom     1
#            21165      BEWARE OF THE CAT METAL SIGN          12       5/19/2011 19:51   1.69       18225.0     United Kingdom     1
#            21080      SET/20 RED RETROSPOT PAPER NAPKINS    12       5/19/2011 19:51   0.85       18225.0     United Kingdom     1
#            21078      SET/20 STRAWBERRY PAPER NAPKINS       12       5/19/2011 19:51   0.85       18225.0     United Kingdom     1
# C581569    84978      HANGING HEART JAR T-LIGHT HOLDER     -1        12/9/2011 11:58   1.25       17315.0     United Kingdom     1
# Length: 401604, dtype: int64

# %% [markdown]
# # **33. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅merge활용 데이터 병합**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 조건에 맞는 데이터를 만들고, 병합하시오**
#
# > **출력형태**
#
# ```
# * CustomerID별 Total Quantity를 계산하고 df1으로 할당
# * CustomerID별 Total UnitPrice를 계산하고 df2으로 할당
# * CusomerID를 Key로 설정하여 df1과 df2를 merge
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ groupby 명령어를 통해 집계 
df1 = df.groupby('CustomerID')['Quantity'].sum()
df2 = df.groupby('CustomerID')['UnitPrice'].sum()

# %%
# ▶ merge를 활용하여 customerID 기중으로 join
df3 = pd.merge(df1,df2, on='CustomerID', how='left')
df3.head()
# Out:
#             Quantity  UnitPrice
# CustomerID
# 12346.0            0       2.08
# 12347.0         2458     481.21
# 12348.0         2341     178.71
# 12349.0          631     605.10
# 12350.0          197      65.30

# %% [markdown]
# # **34. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅line plot 그리기 (1)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 조건에 맞는 데이터를 추출하고 시각화하시오**
#
# > **출력형태**
#
# ```
# * 월 별 Unique한 CustomerID를 계산하고, 월 별 Line Plot을 그리시오
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 월 별 유니크한 구매 고객수 집계
df.groupby('InvoiceDate')['CustomerID'].nunique()
# Out:
# InvoiceDate
# 2010-12     948
# 2011-01     783
# 2011-02     798
# 2011-03    1020
# 2011-04     899
# 2011-05    1079
# 2011-06    1051
# 2011-07     993
# 2011-08     980
# 2011-09    1302
# 2011-10    1425
# 2011-11    1711
# 2011-12     686
# Name: CustomerID, dtype: int64

# %%
# ▶ 기본 Lineplot 출력
import matplotlib.pyplot as plt
plt.plot(df.groupby('InvoiceDate')['CustomerID'].nunique());
plt.gcf().set_size_inches(20, 5)

# %% [markdown]
# # **35. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅line plot 그리기 (2)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,조건에 맞는 데이터를 추출하고 그래프를 그리시오**
#
# > **출력형태**
#
# ```
# * 월별 구매한 유니크한 고객의 수를 계산
# * 29번 문제 참고
# * 상위 값을 구할 때 벌크 고객과 일반고객을 나누어 계산하고, 그래프를 하나의 영역에 각각 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 조건에 맞게 bulk와 normal을 부여 
df['buy_type'] = np.where(df['Quantity'] >=100, 'bulk', 'normal')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country buy_type
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   normal
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom   normal
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom   normal
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom   normal
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom   normal

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ ['InvoiceDate','buy_type'] 기준으로 데이터를 다시 집계 
df3 = df.groupby(['InvoiceDate','buy_type'])['CustomerID'].nunique().reset_index()
df3.head()
# Out:
#   InvoiceDate buy_type  CustomerID
# 0     2010-12     bulk          99
# 1     2010-12   normal         931
# 2     2011-01     bulk         100
# 3     2011-01   normal         773
# 4     2011-02     bulk          89

# %%
# ▶ 2가지 조건을 각각 plot
plt.plot(df3[df3['buy_type']=='normal']['InvoiceDate'], df3[df3['buy_type']=='normal']['CustomerID'], label = 'normal')
plt.plot(df3[df3['buy_type']=='bulk']['InvoiceDate'], df3[df3['buy_type']=='bulk']['CustomerID'], label = 'bulk')
plt.legend()
plt.gcf().set_size_inches(15, 5)

# %% [markdown]
# # **36. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅그래프 Color 변경**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,조건에 맞는 데이터를 추출하고 그래프를 그리시오**
#
# > **출력형태**
#
# ```
# * 35번 문제와 동일한 데이터 활용하여, 그래프를 출력
# * normal은 'pink', bulk는 'green'으로 표현하여 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ bulk, normal 부여 
df['buy_type'] = np.where(df['Quantity'] >=100, 'bulk', 'normal')

# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출

# %%
df3 = df.groupby(['InvoiceDate','buy_type'])['CustomerID'].nunique().reset_index()

# %%
# ▶ color 옵션을 통해 색상 부여 및 legned() 옵션을 통해 범례 출력 
plt.plot(df3[df3['buy_type']=='normal']['InvoiceDate'], df3[df3['buy_type']=='normal']['CustomerID'], label = 'normal', color='pink')
plt.plot(df3[df3['buy_type']=='bulk']['InvoiceDate'], df3[df3['buy_type']=='bulk']['CustomerID'], label = 'bulk', color='green')
plt.legend()
plt.gcf().set_size_inches(15, 5)

# %% [markdown]
# # **37. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅Catplot 그리기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, catplot을 활용하여 범주형 변수를 표현하시오**
#
# > **출력형태**
#
# ```
# * value_counts() 명령어를 사용하여 상위 Top10 국가에 대해 새로운 DF를 생성
# * catplot을 활용하여 Country의 count를 표현
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ value_counts() 명령어를 통해 가장 카운트가 많은 상위 10개의 국가를 필터링
df1 = pd.DataFrame(df['Country'].value_counts().head(10))
df1
# Out:
#                 Country
# United Kingdom   495478
# Germany            9495
# France             8557
# EIRE               8196
# Spain              2533
# Netherlands        2371
# Belgium            2069
# Switzerland        2002
# Portugal           1519
# Australia          1259

# %%
# ▶ 상위 10개의 국가를 리스트로 변경
list(df1.index)
# Out:
# ['United Kingdom',
#  'Germany',
#  'France',
#  'EIRE',
#  'Spain',
#  'Netherlands',
#  'Belgium',
#  'Switzerland',
#  'Portugal',
#  'Australia']

# %%
# ▶ isin명려어를 통해 상위 10개의 국가의 데이터만 가져와서 df2를 생성
df2 = df[df['Country'].isin(list(df1.index))]

# %%
# ▶ catplot 시각화
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use(['dark_background'])

sns.catplot(x="Country", kind="count",palette="pastel", edgecolor=".6",data=df2);
plt.gcf().set_size_inches(10, 6)

# %% [markdown]
# # **39. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅월별 구매수량 Boxplot 그리기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, Box-plot을 시각화하시오**
#
# > **출력형태**
#
# ```
# * 년월 변수를 추출하고, Quantity 대상으로 Boxplot 시각화
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출

# %%
# ▶ boxplot 명령어를 통해 시각화
sns.boxplot(x='InvoiceDate', y='Quantity', data= df)
plt.gcf().set_size_inches(10, 10)
# Out:
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\Users\Jarvis\anaconda3\envs\machine_learning\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # **40. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅특정 값 포함한 행 찾기 (2)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 다음 조건을 만족하는 데이터를 추출하시오**
#
# > **출력형태**
#
# ```
# * Description col에 'BOTTLE'과 'HANGER'가 포함된 모든 row를 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ str.contains를 사용하고, 문자열 입력시 '|' 연산자를 통해 2가지 이상의 문자열을 포함시킨 row를 찾을 수 있음
df[df['Description'].str.contains('BOTTLE|HANGER',na=False)]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 51        536373    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 61        536373    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 68        536375    84406B       CREAM CUPID HEARTS COAT HANGER         8
# ...          ...       ...                                  ...       ...
# 541751    581572     23328   SET 6 SCHOOL MILK BOTTLES IN CRATE        48
# 541870    581585     22915        ASSORTED BOTTLE TOP  MAGNETS         24
# 541877    581585     22113          GREY HEART HOT WATER BOTTLE         4
# 541878    581585     23356                LOVE HOT WATER BOTTLE         3
# 541887    581585     23328   SET 6 SCHOOL MILK BOTTLES IN CRATE         4
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 51       12/1/2010 9:02       2.75     17850.0  United Kingdom
# 61       12/1/2010 9:02       3.39     17850.0  United Kingdom
# 68       12/1/2010 9:32       2.75     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541751  12/9/2011 12:08       3.39     16705.0  United Kingdom
# 541870  12/9/2011 12:31       0.19     15804.0  United Kingdom
# 541877  12/9/2011 12:31       4.25     15804.0  United Kingdom
# 541878  12/9/2011 12:31       5.95     15804.0  United Kingdom
# 541887  12/9/2011 12:31       3.75     15804.0  United Kingdom
#
# [14734 rows x 8 columns]

# %% [markdown]
# # **41. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅다양한 방법을 통해 컬럼 Select하기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 특정 Col을 Select하시오**
#
# > **출력형태**
#
# ```
# * 원하는 방법 중 3가지 방법으로 다음 col을 추출
# * InvoiceDate, CustomerID, Description
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ (1) [[]] 방법 
df1 = df[['InvoiceDate', 'CustomerID', 'Description']]
df1.head()
# Out:
#       InvoiceDate  CustomerID                          Description
# 0  12/1/2010 8:26     17850.0   WHITE HANGING HEART T-LIGHT HOLDER
# 1  12/1/2010 8:26     17850.0                  WHITE METAL LANTERN
# 2  12/1/2010 8:26     17850.0       CREAM CUPID HEARTS COAT HANGER
# 3  12/1/2010 8:26     17850.0  KNITTED UNION FLAG HOT WATER BOTTLE
# 4  12/1/2010 8:26     17850.0       RED WOOLLY HOTTIE WHITE HEART.

# %%
# ▶ (2) drop 방법
df2 = df.drop(['InvoiceNo', 'StockCode', 'Quantity', 'UnitPrice', 'Country'], axis=1)
df2.head()
# Out:
#                            Description     InvoiceDate  CustomerID
# 0   WHITE HANGING HEART T-LIGHT HOLDER  12/1/2010 8:26     17850.0
# 1                  WHITE METAL LANTERN  12/1/2010 8:26     17850.0
# 2       CREAM CUPID HEARTS COAT HANGER  12/1/2010 8:26     17850.0
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  12/1/2010 8:26     17850.0
# 4       RED WOOLLY HOTTIE WHITE HEART.  12/1/2010 8:26     17850.0

# %%
df3 = df.filter(items=['InvoiceDate', 'CustomerID', 'Description'], axis=0)
df3.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
# ▶ (3) filter 방법
df3 = df.filter(items=['InvoiceDate', 'CustomerID', 'Description'], axis=1)
df3.head()
# Out:
#       InvoiceDate  CustomerID                          Description
# 0  12/1/2010 8:26     17850.0   WHITE HANGING HEART T-LIGHT HOLDER
# 1  12/1/2010 8:26     17850.0                  WHITE METAL LANTERN
# 2  12/1/2010 8:26     17850.0       CREAM CUPID HEARTS COAT HANGER
# 3  12/1/2010 8:26     17850.0  KNITTED UNION FLAG HOT WATER BOTTLE
# 4  12/1/2010 8:26     17850.0       RED WOOLLY HOTTIE WHITE HEART.

# %% [markdown]
# # **42. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅그래프에 수평,수직선 추가하기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,조건에 맞는 데이터를 추출하고 시각화하시오**
#
# > **출력형태**
#
# ```
# * 년월별 유니크한 고객 수를 추출
# * 모든 년월의 평균 구매 고객수의 값을 수평선으로 표현
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 년월별 구매한 고객 수(Unique)
df.groupby('InvoiceDate')['CustomerID'].nunique()
# Out:
# InvoiceDate
# 2010-12     948
# 2011-01     783
# 2011-02     798
# 2011-03    1020
# 2011-04     899
# 2011-05    1079
# 2011-06    1051
# 2011-07     993
# 2011-08     980
# 2011-09    1302
# 2011-10    1425
# 2011-11    1711
# 2011-12     686
# Name: CustomerID, dtype: int64

# %%
# ▶ 수평선을 그리기 위한 값 선정
df.groupby('InvoiceDate')['CustomerID'].nunique().mean()
# Out:
# 1051.923076923077

# %%
import matplotlib.pyplot as plt
# ▶ plot을 그리고, axhline 명령어를 통해 수평선 추가, 수평선 값은 상위 단계에서 구한 평균값을 활용
# xmin=0, xmax=1로 설정할 시 그래프의 처음부터 끝까지 수평선이 추가됨
plt.plot(df.groupby('InvoiceDate')['CustomerID'].nunique());
plt.axhline(y=df.groupby('InvoiceDate')['CustomerID'].nunique().mean(), xmin=0, xmax=1, color='blue', linestyle='dashed')
plt.gcf().set_size_inches(20, 5)

# %% [markdown]
# # **43. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅축 이름 설정**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 조건에 데이터를 추출하고 시각화하시오**
#
# > **출력형태**
#
# ```
# * 42번문제와 동일한 데이터를 사용하고, x축과 y축에 레이블을 입력
# * x축 : 'BSYM' / y축 : 'MAU'
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 년월별 구매한 고객 수(Unique)
df.groupby('InvoiceDate')['CustomerID'].nunique()
# Out:
# InvoiceDate
# 2010-12     948
# 2011-01     783
# 2011-02     798
# 2011-03    1020
# 2011-04     899
# 2011-05    1079
# 2011-06    1051
# 2011-07     993
# 2011-08     980
# 2011-09    1302
# 2011-10    1425
# 2011-11    1711
# 2011-12     686
# Name: CustomerID, dtype: int64

# %%
# ▶ 수평선을 그리기 위한 값 선정
df.groupby('InvoiceDate')['CustomerID'].nunique().mean()
# Out:
# 1051.923076923077

# %%
import matplotlib.pyplot as plt
# ▶ plot을 그리고, axhline 명령어를 통해 수평선 추가, 수평선 값은 상위 단계에서 구한 평균값을 활용
# xmin=0, xmax=1로 설정할 시 그래프의 처음부터 끝까지 수평선이 추가됨
plt.plot(df.groupby('InvoiceDate')['CustomerID'].nunique());
plt.axhline(y=df.groupby('InvoiceDate')['CustomerID'].nunique().mean(), xmin=0, xmax=1, color='blue', linestyle='dashed')
plt.xlabel('BSYM', fontsize=16) # xlabel 이름 설정
plt.ylabel('MAU', fontsize=16) # ylabel 이름 설정
plt.gcf().set_size_inches(20, 5)

# %% [markdown]
# # **44. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅이중축 그래프 그리기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 조건에 맞는 데이터를 추출하고 시각화하시오**
#
# > **출력형태**
#
# ```
# * 월별 유니크한 구매 고객수(MAU)를 추출
# * 월별 객단가(Total 구매 금액 / MAU) 추출
# * 상위 2개의 데이터를 활용하여 이중축 그래프 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 국가별 유니크한 고객ID를 집계하여 df1에 할당
df1 = df.groupby('InvoiceDate')['CustomerID'].nunique()
df1
# Out:
# InvoiceDate
# 2010-12     948
# 2011-01     783
# 2011-02     798
# 2011-03    1020
# 2011-04     899
# 2011-05    1079
# 2011-06    1051
# 2011-07     993
# 2011-08     980
# 2011-09    1302
# 2011-10    1425
# 2011-11    1711
# 2011-12     686
# Name: CustomerID, dtype: int64

# %%
# ▶ UnitPrice와 Quantity를 곱하여 Amt Col을 생성하고, 국가별 Amt를 집계하여 df2에 할당
df['Amt'] = df['UnitPrice'] * df['Quantity']
df2 = df.groupby('InvoiceDate')['Amt'].sum()
df2
# Out:
# InvoiceDate
# 2010-12     748957.020
# 2011-01     560000.260
# 2011-02     498062.650
# 2011-03     683267.080
# 2011-04     493207.121
# 2011-05     723333.510
# 2011-06     691123.120
# 2011-07     681300.111
# 2011-08     682680.510
# 2011-09    1019687.622
# 2011-10    1070704.670
# 2011-11    1461756.250
# 2011-12     433668.010
# Name: Amt, dtype: float64

# %%
# ▶ df1과 df2를 열 기준으로 Concat하고, Amt를 CustomerID로 나누어 국가별 객단가를 산출함
df3 = pd.concat([df1,df2], axis=1)
df3['CustomerTransaction'] = df3['Amt'] / df3['CustomerID']
df3
# Out:
#              CustomerID          Amt  CustomerTransaction
# InvoiceDate
# 2010-12             948   748957.020           790.039051
# 2011-01             783   560000.260           715.198289
# 2011-02             798   498062.650           624.138659
# 2011-03            1020   683267.080           669.869686
# 2011-04             899   493207.121           548.617487
# 2011-05            1079   723333.510           670.373967
# 2011-06            1051   691123.120           657.586223
# 2011-07             993   681300.111           686.102831
# 2011-08             980   682680.510           696.612765
# 2011-09            1302  1019687.622           783.170217
# 2011-10            1425  1070704.670           751.371698
# 2011-11            1711  1461756.250           854.328609
# 2011-12             686   433668.010           632.169111

# %%
# ▶ 이중축 그래프 
fig, ax1 = plt.subplots()
color_1 = 'tab:blue' # 색상
ax1.set_title('Plot with 2 Axes for a dataset with different scales', fontsize=16) # 제목
ax1.set_xlabel('BSYM') # x label
ax1.set_ylabel('Y1 value (blue)', fontsize=14, color=color_1) # y label
ax1.plot(df3.index, df3['CustomerID'], marker='s', color=color_1) # line plot 
ax1.tick_params(axis='y', labelcolor=color_1) # ticker paramter 선언


ax2 = ax1.twinx() # 이중 축 
color_2 = 'tab:red' # 색상
ax2.set_ylabel('Y2 value (red)', fontsize=14, color=color_2) # y label
ax2.plot(df3.index, df3['CustomerTransaction'], marker='o', color=color_2) # line plot 
ax2.tick_params(axis='y', labelcolor=color_2) # ticker paramter 선언

fig.tight_layout()
plt.gcf().set_size_inches(20, 5)
plt.show()

# %% [markdown]
# # **45. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅산점도 그리기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 주어진 조건에 맞게 데이터를 추출하고 그래프를 시각화하시오**
#
# > **출력형태**
#
# ```
# * 44번 동일 데이터셋 사용
# * CustomerID와 CustomerTransaction을 활용하여 산점도를 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 국가별 유니크한 고객ID를 집계하여 df1에 할당
df1 = df.groupby('InvoiceDate')['CustomerID'].nunique()
df1
# Out:
# InvoiceDate
# 2010-12     948
# 2011-01     783
# 2011-02     798
# 2011-03    1020
# 2011-04     899
# 2011-05    1079
# 2011-06    1051
# 2011-07     993
# 2011-08     980
# 2011-09    1302
# 2011-10    1425
# 2011-11    1711
# 2011-12     686
# Name: CustomerID, dtype: int64

# %%
# ▶ UnitPrice와 Quantity를 곱하여 Amt Col을 생성하고, 국가별 Amt를 집계하여 df2에 할당
df['Amt'] = df['UnitPrice'] * df['Quantity']
df2 = df.groupby('InvoiceDate')['Amt'].sum()
df2
# Out:
# InvoiceDate
# 2010-12     748957.020
# 2011-01     560000.260
# 2011-02     498062.650
# 2011-03     683267.080
# 2011-04     493207.121
# 2011-05     723333.510
# 2011-06     691123.120
# 2011-07     681300.111
# 2011-08     682680.510
# 2011-09    1019687.622
# 2011-10    1070704.670
# 2011-11    1461756.250
# 2011-12     433668.010
# Name: Amt, dtype: float64

# %%
# ▶ df1과 df2를 열 기준으로 Concat하고, Amt를 CustomerID로 나누어 국가별 객단가를 산출함
df3 = pd.concat([df1,df2], axis=1)
df3['CustomerTransaction'] = df3['Amt'] / df3['CustomerID']
df3
# Out:
#              CustomerID          Amt  CustomerTransaction
# InvoiceDate
# 2010-12             948   748957.020           790.039051
# 2011-01             783   560000.260           715.198289
# 2011-02             798   498062.650           624.138659
# 2011-03            1020   683267.080           669.869686
# 2011-04             899   493207.121           548.617487
# 2011-05            1079   723333.510           670.373967
# 2011-06            1051   691123.120           657.586223
# 2011-07             993   681300.111           686.102831
# 2011-08             980   682680.510           696.612765
# 2011-09            1302  1019687.622           783.170217
# 2011-10            1425  1070704.670           751.371698
# 2011-11            1711  1461756.250           854.328609
# 2011-12             686   433668.010           632.169111

# %%
# ▶ sns scatterplot을 활용하여 그래프를 출력 
import seaborn as sns
sns.scatterplot(x='CustomerID', y='CustomerTransaction', alpha=0.5, data=df3)
# Out:
# <Axes: xlabel='CustomerID', ylabel='CustomerTransaction'>

# %% [markdown]
# # **46. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅plotly 활용 bar 그래프 그리기**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 조건에 맞게 데이터를 출력하고 시각화하시오**
#
# > **출력형태**
#
# ```
# * 46번 동일 데이터 사용
# * Plotly 라이브러리를 활용하여 년월별 MAU를 Bar 그래프로 출력
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 국가별 유니크한 고객ID를 집계하여 df1에 할당
df1 = df.groupby('InvoiceDate')['CustomerID'].nunique()
df1
# Out:
# InvoiceDate
# 2010-12     948
# 2011-01     783
# 2011-02     798
# 2011-03    1020
# 2011-04     899
# 2011-05    1079
# 2011-06    1051
# 2011-07     993
# 2011-08     980
# 2011-09    1302
# 2011-10    1425
# 2011-11    1711
# 2011-12     686
# Name: CustomerID, dtype: int64

# %%
# ▶ UnitPrice와 Quantity를 곱하여 Amt Col을 생성하고, 국가별 Amt를 집계하여 df2에 할당
df['Amt'] = df['UnitPrice'] * df['Quantity']
df2 = df.groupby('InvoiceDate')['Amt'].sum()
df2
# Out:
# InvoiceDate
# 2010-12     748957.020
# 2011-01     560000.260
# 2011-02     498062.650
# 2011-03     683267.080
# 2011-04     493207.121
# 2011-05     723333.510
# 2011-06     691123.120
# 2011-07     681300.111
# 2011-08     682680.510
# 2011-09    1019687.622
# 2011-10    1070704.670
# 2011-11    1461756.250
# 2011-12     433668.010
# Name: Amt, dtype: float64

# %%
# ▶ df1과 df2를 열 기준으로 Concat하고, Amt를 CustomerID로 나누어 국가별 객단가를 산출함
df3 = pd.concat([df1,df2], axis=1)
df3['CustomerTransaction'] = df3['Amt'] / df3['CustomerID']
df3
# Out:
#              CustomerID          Amt  CustomerTransaction
# InvoiceDate
# 2010-12             948   748957.020           790.039051
# 2011-01             783   560000.260           715.198289
# 2011-02             798   498062.650           624.138659
# 2011-03            1020   683267.080           669.869686
# 2011-04             899   493207.121           548.617487
# 2011-05            1079   723333.510           670.373967
# 2011-06            1051   691123.120           657.586223
# 2011-07             993   681300.111           686.102831
# 2011-08             980   682680.510           696.612765
# 2011-09            1302  1019687.622           783.170217
# 2011-10            1425  1070704.670           751.371698
# 2011-11            1711  1461756.250           854.328609
# 2011-12             686   433668.010           632.169111

# %%
# ▶ plotly package를 load하고, px.bar 명령어를 통해 시각화
# fig.update_layout 옵션을 통해 크기를 조절할 수 있음 
import plotly.express as px
fig = px.bar(df3['CustomerID'])
fig.update_layout(height=300 , width=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3d626515-ff02-4039-bfd3-889dd3db1e75" class="plotly-graph-div" style="height:300px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d626515-ff02-4039-bfd3-889dd3db1e75")) {                    Plotly.newPlot(                        "3d626515-ff02-4039-bfd3-889dd3db1e75",                        [{"alignmentgroup":"True","hovertemplate":"variable=CustomerID<br>InvoiceDate=%{x}<br>value=%{y}<extra></extra>","legendgroup":"CustomerID","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"CustomerID","offsetgroup":"CustomerID","orientation":"v","showlegend":true,"textposition":"auto","x":["2010-12","2011-01","2011-02","2011-03","2011-04","2011-05","2011-06","2011-07","2011-08","2011-09","2011-10","2011-11","2011-12"],"xaxis":"x","y":[948,783,798,1020,899,1079,1051,993,980,1302,1425,1711,686],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{ ...

# %% [markdown]
# # **47. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅테이블 데이터 그라데이션 표현**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,조건에 맞게 데이터를 출력하고 시각화하시오**
#
# > **출력형태**
#
# ```
# * 46번 동일 데이터셋 활용
# * style.background_gradient 활용하여 시각화 표현
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ 년월을 추출하기 위해 pd.to_datetime 명령어를 통해 InvoiceDate 컬럼을 시간형태 데이터 타입으로 변환
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceDate'] = df['InvoiceDate'].dt.strftime("%Y-%m") # 시간형태 데이터 타입에 적용할 수 있는 .dt.strftiem(포맷변경)를 적용하여 년월을 추출
df['InvoiceDate'].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceDate, dtype: object

# %%
# ▶ 국가별 유니크한 고객ID를 집계하여 df1에 할당
df1 = df.groupby('InvoiceDate')['CustomerID'].nunique()
df1
# Out:
# InvoiceDate
# 2010-12     948
# 2011-01     783
# 2011-02     798
# 2011-03    1020
# 2011-04     899
# 2011-05    1079
# 2011-06    1051
# 2011-07     993
# 2011-08     980
# 2011-09    1302
# 2011-10    1425
# 2011-11    1711
# 2011-12     686
# Name: CustomerID, dtype: int64

# %%
# ▶ UnitPrice와 Quantity를 곱하여 Amt Col을 생성하고, 국가별 Amt를 집계하여 df2에 할당
df['Amt'] = df['UnitPrice'] * df['Quantity']
df2 = df.groupby('InvoiceDate')['Amt'].sum()
df2
# Out:
# InvoiceDate
# 2010-12     748957.020
# 2011-01     560000.260
# 2011-02     498062.650
# 2011-03     683267.080
# 2011-04     493207.121
# 2011-05     723333.510
# 2011-06     691123.120
# 2011-07     681300.111
# 2011-08     682680.510
# 2011-09    1019687.622
# 2011-10    1070704.670
# 2011-11    1461756.250
# 2011-12     433668.010
# Name: Amt, dtype: float64

# %%
# ▶ df1과 df2를 열 기준으로 Concat하고, Amt를 CustomerID로 나누어 국가별 객단가를 산출함
df3 = pd.concat([df1,df2], axis=1)
df3['CustomerTransaction'] = df3['Amt'] / df3['CustomerID']
df3
# Out:
#              CustomerID          Amt  CustomerTransaction
# InvoiceDate
# 2010-12             948   748957.020           790.039051
# 2011-01             783   560000.260           715.198289
# 2011-02             798   498062.650           624.138659
# 2011-03            1020   683267.080           669.869686
# 2011-04             899   493207.121           548.617487
# 2011-05            1079   723333.510           670.373967
# 2011-06            1051   691123.120           657.586223
# 2011-07             993   681300.111           686.102831
# 2011-08             980   682680.510           696.612765
# 2011-09            1302  1019687.622           783.170217
# 2011-10            1425  1070704.670           751.371698
# 2011-11            1711  1461756.250           854.328609
# 2011-12             686   433668.010           632.169111

# %%
# ▶ style.background_gradient를 사용하여 히트맵 차트 표현
# axis 옵션에 따라 히트맵의 적용 범위가 달라짐
# axis = 0 : 행 기준 
# axis = 1 :열 기준
# axis = None : 모든 데이터 
df3.style.background_gradient(cmap='coolwarm', low=1, axis=0)
# Out:
# <style type="text/css">
# #T_91b13_row0_col0, #T_91b13_row6_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_91b13_row0_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_91b13_row0_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_91b13_row1_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_91b13_row1_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_91b13_row1_col2 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_91b13_row2_col0 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_91b13_row2_col1 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_91b13_row2_col2, #T_91b13_row3_col1, #T_91b13_row8_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_91b13_row3_col0 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_91b13_row3_col2, #T_91b13_row5_col2 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_91b13_row4_col0 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_91b13_row4_col1 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_91b13_row4_col2, #T_91b13_row12_col0, #T_91b13_row12_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_91b13_row5_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_91b13_row5_col1, #T_91b13_row8_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_91b13_row6_col0, #T_91b13_row6_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_91b13_row7_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_91b13_row7_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_91b13_row7_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_91b13_row8_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_91b13_row9_col0 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_91b13_row9_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_91b13_row9_col2 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_91b13_row10_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_91b13_row10_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_91b13_row10_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_91b13_row11_col0, #T_91b13_row11_col1, #T_91b13_row11_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_91b13_row12_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# </style>
# <table id="T_91b13" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91b13_level0_col0" class="col_heading level0 col0" >CustomerID</th>
#       <th id="T_91b13_level0_col1" class="col_heading level0 col1" >Amt</th>
#       <th id="T_91b13_level0_col2" class="col_heading level0 col2" >CustomerTransaction</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >InvoiceDate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91b13_level0_row0" class="row_heading level0 row0" >2010-12</th>
#       <td id="T_91b13_row0_col0" class="data row0 col0" >948</td>
#       <td id="T_91b13_row0_col1" class="data row0 col1" >748957.020000</td>
#       <td id="T_91b13_row0_col2" class="data row0 col2" >790.039051</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row1" class="row_heading level0 row1" >2011-01</th>
#       <td id="T_91b13_row1_col0" class="data row1 col0" >783</td>
#       <td id="T_91b13_row1_col1" class="data row1 col1" >560000.260000</td>
#       <td id="T_91b13_row1_col2" class="data row1 col2" >715.198289</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row2" class="row_heading level0 row2" >2011-02</th>
#       <td id="T_91b13_row2_col0" class="data row2 col0" >798</td>
#       <td id="T_91b13_row2_col1" class="data row2 col1" >498062.650000</td>
#       <td id="T_91b13_row2_col2" class="data row2 col2" >624.138659</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row3" class="row_heading level0 row3" >2011-03</th>
#       <td id="T_91b13_row3_col0" class="data row3 col0" >1020</td>
#       <td id="T_91b13_row3_col1" class="data row3 col1" >683267.080000</td>
#       <td id="T_91b13_row3_col2" class="data row3 col2" >669.869686</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row4" class="row_heading level0 row4" >2011-04</th>
#       <td id="T_91b13_row4_col0" class="data row4 col0" >899</td>
#       <td id="T_91b13_row4_col1" class="data row4 col1" >493207.121000</td>
#       <td id="T_91b13_row4_col2" class="data row4 col2" >548.617487</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row5" class="row_heading level0 row5" >2011-05</th>
#       <td id="T_91b13_row5_col0" class="data row5 col0" >1079</td>
#       <td id="T_91b13_row5_col1" class="data row5 col1" >723333.510000</td>
#       <td id="T_91b13_row5_col2" class="data row5 col2" >670.373967</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row6" class="row_heading level0 row6" >2011-06</th>
#       <td id="T_91b13_row6_col0" class="data row6 col0" >1051</td>
#       <td id="T_91b13_row6_col1" class="data row6 col1" >691123.120000</td>
#       <td id="T_91b13_row6_col2" class="data row6 col2" >657.586223</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row7" class="row_heading level0 row7" >2011-07</th>
#       <td id="T_91b13_row7_col0" class="data row7 col0" >993</td>
#       <td id="T_91b13_row7_col1" class="data row7 col1" >681300.111000</td>
#       <td id="T_91b13_row7_col2" class="data row7 col2" >686.102831</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row8" class="row_heading level0 row8" >2011-08</th>
#       <td id="T_91b13_row8_col0" class="data row8 col0" >980</td>
#       <td id="T_91b13_row8_col1" class="data row8 col1" >682680.510000</td>
#       <td id="T_91b13_row8_col2" class="data row8 col2" >696.612765</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row9" class="row_heading level0 row9" >2011-09</th>
#       <td id="T_91b13_row9_col0" class="data row9 col0" >1302</td>
#       <td id="T_91b13_row9_col1" class="data row9 col1" >1019687.622000</td>
#       <td id="T_91b13_row9_col2" class="data row9 col2" >783.170217</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row10" class="row_heading level0 row10" >2011-10</th>
#       <td id="T_91b13_row10_col0" class="data row10 col0" >1425</td>
#       <td id="T_91b13_row10_col1" class="data row10 col1" >1070704.670000</td>
#       <td id="T_91b13_row10_col2" class="data row10 col2" >751.371698</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row11" class="row_heading level0 row11" >2011-11</th>
#       <td id="T_91b13_row11_col0" class="data row11 col0" >1711</td>
#       <td id="T_91b13_row11_col1" class="data row11 col1" >1461756.250000</td>
#       <td id="T_91b13_row11_col2" class="data row11 col2" >854.328609</td>
#     </tr>
#     <tr>
#       <th id="T_91b13_level0_row12" class="row_heading level0 row12" >2011-12</th>
#       <td id="T_91b13_row12_col0" class="data row12 col0" >686</td>
#       <td id="T_91b13_row12_col1" class="data row12 col1" >433668.010000</td>
#       <td id="T_91b13_row12_col2" class="data row12 col2" >632.169111</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # **48. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅이중 조건문**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고,이중 조건문을 활용하여 구분자를 생성하시오**
#
# > **출력형태**
#
# ```
# * Country가 United Kingdom인 경우 'UK', Germany인 경우 'GR' 그 밖에 'etc'로 처리
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ Value_counts()를 통해 현재 구성되어 있는 국가 데이터 확인
df['Country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %%
# ▶ np.where을 두번 사용하여 이중 조건문 완성
df['Country'] = np.where(df['Country']=='United Kingdom', 'UK', 
                         np.where(df['Country']=='Germany', 'GR', 'etc')
                         )
df['Country'].value_counts()
# Out:
# UK     495478
# etc     36936
# GR       9495
# Name: Country, dtype: int64

# %% [markdown]
# # **49. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅데이터 가공 및 추출 (1)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 주어진 조건에 맞는 데이터를 추출하시오**
#
# > **출력형태**
#
# ```
# * Country별 객단가(CustomerTransaction)을 추출
# * CustomerTransaction = Total amt / MAU
# * 46번 문제 참고
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ UnitPrice와 Quantity를 곱하여 Amt Col 생성
df['Amt'] = df['UnitPrice'] * df['Quantity']

# %%
# ▶ 국가별 유니크한 고객ID를 집계하여 df1에 할당하고, 국가별 Amt를 집계하여 df2에 할당
df1 = df.groupby('Country')['CustomerID'].nunique()
df2 = df.groupby('Country')['Amt'].sum()

# %%
# ▶ df1과 df2를 열 기준으로 Concat하고, Amt를 CustomerID로 나누어 국가별 객단가를 산출함
df3 = pd.concat([df1,df2], axis=1)
df3['CustomerTransaction'] = df3['Amt'] / df3['CustomerID']
df3
# Out:
#                       CustomerID          Amt  CustomerTransaction
# Country
# Australia                      9   137077.270         1.523081e+04
# Austria                       11    10154.320         9.231200e+02
# Bahrain                        2      548.400         2.742000e+02
# Belgium                       25    40910.960         1.636438e+03
# Brazil                         1     1143.600         1.143600e+03
# Canada                         4     3666.380         9.165950e+02
# Channel Islands                9    20086.290         2.231810e+03
# Cyprus                         8    12946.290         1.618286e+03
# Czech Republic                 1      707.720         7.077200e+02
# Denmark                        9    18768.140         2.085349e+03
# EIRE                           3   263276.820         8.775894e+04
# European Community             1     1291.750         1.291750e+03
# Finland                       12    22326.740         1.860562e+03
# France                        87   197403.900         2.269010e+03
# Germany                       95   221698.210         2.333665e+03
# Greece                         4     4710.520         1.177630e+03
# Hong Kong                      0    10117.040                  inf
# Iceland                        1     4310.000         4.310000e+03
# Israel                         4     7907.820         1.976955e+03
# Italy                         15    16890.510         1.126034e+03
# Japan                          8    35340.620         4.417578e+03
# Lebanon                        1     1693.880         1.693880e+03
# Lithuania                      1     1661.060         1.661060e+03
# Malta                          2     2505.470         1.252735e+03
# Netherlands                    9   284661.540         3.162906e+04
# Norway                        10    35163.460         3.516346e+03
# Poland                         6     7213.140         1.202190e+03
# Portugal                      19    29367.020         1.545633e+03
# RSA                            1     1002.310         1.002310e+03
# Saudi Arabia                   1      131.170         1.311700e+02
# Singapore                      1     9120.390         9.120390e+03
# Spain                         31    54774.580         1.766922e+03
# Sweden                         8    36595.910         4.574489e+03
# Switzerland                   21    56385.350         2.685017e+03
# USA                            4     1730.920         4.327300e+02
# United Arab Emirates           2     1902.280         9.511400e+02
# United Kingdom              3950  8187806.364         2.072862e+03
# Unspecified                    4     4749.790         1.187447e+03

# %% [markdown]
# # **50. PROC 문제**
# ---

# %% [markdown]
# #**┗ ✅데이터 가공 및 추출 (2)**

# %% [markdown]
# ## **🔒문제설명**
# ---
# * **주어진 Data를 Read하고, 조건에 맞게 데이터를 추출하시오**
#
# > **출력형태**
#
# ```
# * 49번 문제에서 inf(무한대)로 표현된 데이터를 0으로 처리
# ```

# %%
# ▶ Data read  (※ 추가 수정 없이, 상위 단계에서 경로 설정 후 실행)
import pandas as pd
import numpy as np
df = pd.read_csv('exam01.csv', encoding='ISO-8859-1')
df.head()

# %% [markdown]
# ## **🔑풀이설명**
# ---
# > **문제풀이**

# %%
# ▶ UnitPrice와 Quantity를 곱하여 Amt Col 생성
df['Amt'] = df['UnitPrice'] * df['Quantity']

# %%
# ▶ 국가별 유니크한 고객ID를 집계하여 df1에 할당하고, 국가별 Amt를 집계하여 df2에 할당
df1 = df.groupby('Country')['CustomerID'].nunique()
df2 = df.groupby('Country')['Amt'].sum()

# %%
# ▶ df1과 df2를 열 기준으로 Concat하고, Amt를 CustomerID로 나누어 국가별 객단가를 산출함
df3 = pd.concat([df1,df2], axis=1)
df3['CustomerTransaction'] = df3['Amt'] / df3['CustomerID']
df3
# Out:
#                       CustomerID          Amt  CustomerTransaction
# Country
# Australia                      9   137077.270         1.523081e+04
# Austria                       11    10154.320         9.231200e+02
# Bahrain                        2      548.400         2.742000e+02
# Belgium                       25    40910.960         1.636438e+03
# Brazil                         1     1143.600         1.143600e+03
# Canada                         4     3666.380         9.165950e+02
# Channel Islands                9    20086.290         2.231810e+03
# Cyprus                         8    12946.290         1.618286e+03
# Czech Republic                 1      707.720         7.077200e+02
# Denmark                        9    18768.140         2.085349e+03
# EIRE                           3   263276.820         8.775894e+04
# European Community             1     1291.750         1.291750e+03
# Finland                       12    22326.740         1.860562e+03
# France                        87   197403.900         2.269010e+03
# Germany                       95   221698.210         2.333665e+03
# Greece                         4     4710.520         1.177630e+03
# Hong Kong                      0    10117.040                  inf
# Iceland                        1     4310.000         4.310000e+03
# Israel                         4     7907.820         1.976955e+03
# Italy                         15    16890.510         1.126034e+03
# Japan                          8    35340.620         4.417578e+03
# Lebanon                        1     1693.880         1.693880e+03
# Lithuania                      1     1661.060         1.661060e+03
# Malta                          2     2505.470         1.252735e+03
# Netherlands                    9   284661.540         3.162906e+04
# Norway                        10    35163.460         3.516346e+03
# Poland                         6     7213.140         1.202190e+03
# Portugal                      19    29367.020         1.545633e+03
# RSA                            1     1002.310         1.002310e+03
# Saudi Arabia                   1      131.170         1.311700e+02
# Singapore                      1     9120.390         9.120390e+03
# Spain                         31    54774.580         1.766922e+03
# Sweden                         8    36595.910         4.574489e+03
# Switzerland                   21    56385.350         2.685017e+03
# USA                            4     1730.920         4.327300e+02
# United Arab Emirates           2     1902.280         9.511400e+02
# United Kingdom              3950  8187806.364         2.072862e+03
# Unspecified                    4     4749.790         1.187447e+03

# %%
# ▶ inf로 선언된 값을 변경하기 위해 replace 명령어를 사용하여 np.inf를 0으로 변환
df3['CustomerTransaction'] = df3['CustomerTransaction'].replace(np.inf, 0)

# %%
# ▶ 변환된 데이터 셋 확인
df3
# Out:
#                       CustomerID          Amt  CustomerTransaction
# Country
# Australia                      9   137077.270         15230.807778
# Austria                       11    10154.320           923.120000
# Bahrain                        2      548.400           274.200000
# Belgium                       25    40910.960          1636.438400
# Brazil                         1     1143.600          1143.600000
# Canada                         4     3666.380           916.595000
# Channel Islands                9    20086.290          2231.810000
# Cyprus                         8    12946.290          1618.286250
# Czech Republic                 1      707.720           707.720000
# Denmark                        9    18768.140          2085.348889
# EIRE                           3   263276.820         87758.940000
# European Community             1     1291.750          1291.750000
# Finland                       12    22326.740          1860.561667
# France                        87   197403.900          2269.010345
# Germany                       95   221698.210          2333.665368
# Greece                         4     4710.520          1177.630000
# Hong Kong                      0    10117.040             0.000000
# Iceland                        1     4310.000          4310.000000
# Israel                         4     7907.820          1976.955000
# Italy                         15    16890.510          1126.034000
# Japan                          8    35340.620          4417.577500
# Lebanon                        1     1693.880          1693.880000
# Lithuania                      1     1661.060          1661.060000
# Malta                          2     2505.470          1252.735000
# Netherlands                    9   284661.540         31629.060000
# Norway                        10    35163.460          3516.346000
# Poland                         6     7213.140          1202.190000
# Portugal                      19    29367.020          1545.632632
# RSA                            1     1002.310          1002.310000
# Saudi Arabia                   1      131.170           131.170000
# Singapore                      1     9120.390          9120.390000
# Spain                         31    54774.580          1766.921935
# Sweden                         8    36595.910          4574.488750
# Switzerland                   21    56385.350          2685.016667
# USA                            4     1730.920           432.730000
# United Arab Emirates           2     1902.280           951.140000
# United Kingdom              3950  8187806.364          2072.862371
# Unspecified                    4     4749.790          1187.447500
